# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/ML/blob/main/convolucionTemniado3.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
#@markdown # *1) ** Descargando DataSet  de perros y gatos(OBLIGATORIO)
import zipfile

nombre_zip="data_set_dogcat.zip"

directorio_destino="/content/"

# !gdown --id 19u9sy2053Ds739lyYSJut6S_k54trLnd -O {nombre_zip}

with zipfile.ZipFile(nombre_zip, 'r') as zip_ref:
    zip_ref.extractall(directorio_destino)
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=19u9sy2053Ds739lyYSJut6S_k54trLnd
# To: /content/data_set_dogcat.zip
# 100% 826M/826M [00:16<00:00, 50.1MB/s]

# %%
#@markdown # *1) ** Clase Para manejo de directorios de datasets de imagenes


import os
import cv2
import pandas as pd
from PIL import Image
# Recorre el directorio  y elmiina los archvios que no tiene las extensioens permitidas

class directoriosManage:

 def __init__(self):
     self.mensaje = "Creada instancia"

 def comprobar_ext_directorios(self,directorio):

  for clase,[directorio,etiquetas] in(directorios.items()):
   lista_directorio=os.listdir(directorio)
   self.validarExt(directorio)



 def  validarExt(self,directorio):
  print(directorio)
   # Extensiones permitidas
  extensiones_permitidas = {".jpg", ".jpeg", ".png"}
  for root, dirs, files in os.walk(directorio):

    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")


# Cambia nombre de cada archivo dentro del directorio a un valor secuencial

 def cambiar_nombres_directorios(self,directorio):
   for clase,[directorio,etiquetas] in(directorios.items()):
     lista_directorio=os.listdir(directorio)
     self.cambiarNombre(directorio,clase)


 def cambiarNombre(self,directorio,subfijo):
  archivos_en_directorio = os.listdir(directorio)
  for i, archivo in enumerate(archivos_en_directorio, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorio, archivo)
    ruta_nueva = os.path.join(directorio, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)
    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")

#Obtiene la cantidad de elemntos que tiene la carpeta

 def len_directorio(self,directorio):
    cantidad_elementos = sum(1 for elemento in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, elemento)))
    return cantidad_elementos


#----------------------------------------------------------------------------------------------

#Valida si la imagen se puede leer usando  pill o cv2 si no se puede leer se elimina
 def validar_Img_Pill(self,directorio,):
  for etiqueta,[directorio,clase] in(directorios.items()):

    lista_paths=os.listdir(directorio)
    self.validarLecturaImgPill(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def validar_Img_cv2(self,directorio):
  for etiqueta,[directorio,clase] in(directorios.items()):

    lista_paths=os.listdir(directorio)
    self.validarLecturaImg(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")


 def validarLecturaImg(self,directorio,lista):

  for ruta in(lista):
   imagen=cv2.imread(directorio+ruta)
   if  imagen is None:
     os.remove(directorio+ruta)
     print(f"No se pudo leer y se elimino archivo:{directorio+ruta}")

 def validarLecturaImgPill(self,directorio,lista):
    for ruta in(lista):
     try:
      imagen=Image.open(directorio+ruta)
     except Exception as e:
      os.remove(directorio+ruta)
      print(f"Archivo '{directorio+ruta}' eliminado.")



 def crear_paths_csv(self,directorio_base,lista_paths,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir_path,clase in  zip(directorio_base,lista_paths,clases):

    for path  in (dir_path):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")

#vamos a recorrer el dicionario y validar ruta por ruta si se puede leer sino se elminara
#vamos guaradno al mismo tiempo 3 listas, los directorios , listas de paths de los directiros y de las clases ,para usarlo luego usarlo al crear el csv

 def separar_datos_directorios(self,directorios):
  listas_directorios=[]
  listas_listas_directorios=[]
  listas_clases=[]

  for etiqueta,[directorio,clase] in(directorios.items()):

       lista_paths=os.listdir(directorio)
       listas_directorios.append(directorio)
       listas_listas_directorios.append(lista_paths)
       listas_clases.append(clase)

  return listas_directorios,listas_listas_directorios,listas_clases

 def emparejar_listas_paths(self,lista_listas):

   #Tomamos el minimo tamaño dentro de las lista de cada clase
   tamaño_minimo = min(len(arr) for arr in lista_listas)

   #Vamos a emparejar todas las listas con un tamaño igual que sea la del minimo tamaño de todas,esto para tener un set de datos parejo por cada clase
   Reducido_lista_paths=[]

   #Reduce cada lista de los paths a la cantidad minimo para que todos tenga iaugal cantidad
   for listas in(listas_paths_directorios):
    Reducido_lista_paths.append(listas[:tamaño_minimo])

   return Reducido_lista_paths
#---------------------------------------------------------------------------------

#devuelve cuatnos elemtnos tiene cada clase
 def total_elementos(self,directorio,csv_path):
    df=pd.read_csv(csv_path)
    for clase,[directorio,etiqueta] in (directorios.items()):
     tamaño_etiqueta=(df["etiqueta"] == etiqueta).sum()
     print(f"la clase {clase} tiene :{tamaño_etiqueta} elementos")

# %%
#@markdown # *1) ** Creacion de el csv de los path y clases(OBLIGATORIO)

dmg=directoriosManage()

directorios={
     "gato":["/content/PetImages/Cat/",0],
     "perro":["/content/PetImages/Dog/",1],
}


dmg.comprobar_ext_directorios(directorios)

dmg.cambiar_nombres_directorios(directorios)

dmg.validar_Img_Pill(directorios)

listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directorios)

Reducido_lista_paths=dmg.emparejar_listas_paths(listas_paths_directorios)
#validamos que todas las iamgnes en nuestro direcotrios puedan abrirse con openia cv2



#La funcion que creamos para podre crear nuestro csv , con los parametros antes calucaldos que son 3 listas y el nombre del csv

Dataset_csv="Data_set.csv" #nombre que tendla nuestlo csv
dmg.crear_paths_csv(listas_directorios,Reducido_lista_paths,listas_clases,Dataset_csv)

#imprime total de elemtnos por clase
dmg.total_elementos(directorios,"/content/Data_set.csv")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Se cambió el nombre de /content/PetImages/Dog/7046.jpg a /content/PetImages/Dog/perro7503.jpg
# Se cambió el nombre de /content/PetImages/Dog/4613.jpg a /content/PetImages/Dog/perro7504.jpg
# Se cambió el nombre de /content/PetImages/Dog/740.jpg a /content/PetImages/Dog/perro7505.jpg
# Se cambió el nombre de /content/PetImages/Dog/563.jpg a /content/PetImages/Dog/perro7506.jpg
# Se cambió el nombre de /content/PetImages/Dog/12469.jpg a /content/PetImages/Dog/perro7507.jpg
# Se cambió el nombre de /content/PetImages/Dog/8814.jpg a /content/PetImages/Dog/perro7508.jpg
# Se cambió el nombre de /content/PetImages/Dog/8794.jpg a /content/PetImages/Dog/perro7509.jpg
# Se cambió el nombre de /content/PetImages/Dog/59.jpg a /content/PetImages/Dog/perro7510.jpg
# Se cambió el nombre de /content/PetImages/Dog/2062.jpg a /content/PetImages/Dog/perro7511.jpg
# Se cambió el nombre de /content/PetImages/Dog/2900.jpg a /content/PetImages/Dog/perro7512.jpg
# Se cambió el nombre de /content/PetImages/Dog/9657.jpg a /content/PetImages/Dog/perro7513.jpg
# Se cambió el nombre de /content/PetImages/Dog/11429.jpg a /content/PetImages/Dog/perro7514.jpg
# Se cambió el nombre de /content/PetImages/Dog/3955.jpg a /content/PetImages/Dog/perro7515.jpg
# Se cambió el nombre de /content/PetImages/Dog/10996.jpg a /content/PetImages/Dog/perro7516.jpg
# Se cambió el nombre de /content/PetImages/Dog/829.jpg a /content/PetImages/Dog/perro7517.jpg
# Se cambió el nombre de /content/PetImages/Dog/6972.jpg a /content/PetImages/Dog/perro7518.jpg
# Se cambió el nombre de /content/PetImages/Dog/4636.jpg a /content/PetImages/Dog/perro7519.jpg
# Se cambió el nombre de /content/PetImages/Dog/3024.jpg a /content/PetImages/Dog/perro7520.jpg
# Se cambió el nombre de /content/PetImages/Dog/8156.jpg a /content/PetImages/Dog/perro7521.jpg
# Se cambió el nombre de /content/PetImages/Dog/3699.jpg a /content/PetImages/Dog/perro7522.jpg
# Se cambió el nombre de /content/PetImages/Dog/4904.jpg a /content/PetImages/Dog/perro7523.jpg
# Se cambió el nombre de /content/PetImages/Dog/8371.jpg a /content/PetImages/Dog/perro7524.jpg
# Se cambió el nombre de /content/PetImages/Dog/6569.jpg a /content/PetImages/Dog/perro7525.jpg
# Se cambió el nombre de /content/PetImages/Dog/1668.jpg a /content/PetImages/Dog/perro7526.jpg
# Se cambió el nombre de /content/PetImages/Dog/10662.jpg a /content/PetImages/Dog/perro7527.jpg
# Se cambió el nombre de /content/PetImages/Dog/11437.jpg a /content/PetImages/Dog/perro7528.jpg
# Se cambió el nombre de /content/PetImages/Dog/1074.jpg a /content/PetImages/Dog/perro7529.jpg
# Se cambió el nombre de /content/PetImages/Dog/2242.jpg a /content/PetImages/Dog/perro7530.jpg
# Se cambió el nombre de /content/PetImages/Dog/3818.jpg a /content/PetImages/Dog/perro7531.jpg
# Se cambió el nombre de /content/PetImages/Dog/2434.jpg a /content/PetImages/Dog/perro7532.jpg
# Se cambió el nombre de /content/PetImages/Dog/5830.jpg a /content/PetImages/Dog/perro7533.jpg
# Se cambió el nombre de /content/PetImages/Dog/6437.jpg a /content/PetImages/Dog/perro7534.jpg
# Se cambió el nombre de /content/PetImages/Dog/83.jpg a /content/PetImages/Dog/perro7535.jpg
# Se cambió el nombre de /content/PetImages/Dog/9867.jpg a /content/PetImages/Dog/perro7536.jpg
# Se cambió el nombre de /content/PetImages/Dog/7195.jpg a /content/PetImages/Dog/perro7537.jpg
# Se cambió el nombre de /content/PetImages/Dog/542.jpg a /content/PetImages/Dog/perro7538.jpg
# Se cambió el nombre de /content/PetImages/Dog/41.jpg a /content/PetImages/Dog/perro7539.jpg
# Se cambió el nombre de /content/PetImages/Dog/10931.jpg a /content/PetImages/Dog/perro7540.jpg
# Se cambió el nombre de /content/PetImages/Dog/2232.jpg a /content/PetImages/Dog/perro7541.jpg
# Se cambió el nombre de /content/PetImages/Dog/904.jpg a /content/PetImages/Dog/perro7542.jpg
# Se cambió el nombre de /content/PetImages/Dog/12344.jpg a /content/PetImages/Dog/perro7543.jpg
# Se cambió el nombre de /content/PetImages/Dog/10333.jpg a /content/PetImages/Dog/perro7544.jpg
# Se cambió el nombre de /content/PetImages/Dog/6862.jpg a /content/PetImages/Dog/perro7545.jpg
# Se cambió el nombre de /content/PetImages/Dog/643.jpg a /content/PetImages/Dog/perro7546.jpg
# Se cambió el nombre de /content/PetImages/Dog/6646.jpg a /content/PetImages/Dog/perro7547.jpg
# Se cambió el nombre de /content/PetImages/Dog/9287.jpg a /content/PetImages/Dog/perro7548.jpg
# Se cambió el nombre de /content/PetImages/Dog/3891.jpg a /content/PetImages/Dog/perro7549.jpg
# Se cambió el nombre de /content/PetImages/Dog/7733.jpg a /content/PetImages/Dog/perro7550.jpg
# Se cambió el nombre de /content/PetImages/Dog/4612.jpg a /content/PetImages/Dog/perro7551.jpg
# Se cambió el nombre de /content/PetImages/Dog/5843.jpg a /content/PetImages/Dog/perro7552.jpg
# Se cambió el nombre de /content/PetImages/Dog/3340.jpg a /content/PetImages/Dog/perro7553.jpg
# Se cambió el nombre de /content/PetImages/Dog/1705.jpg a /content/PetImages/Dog/perro7554.jpg
# Se cambió el nombre de /content/PetImages/Dog/3947.jpg a /content/PetImages/Dog/perro7555.jpg
# Se cambió el nombre de /content/PetImages/Dog/1205.jpg a /content/PetImages/Dog/perro7556.jpg
# Se cambió el nombre de /content/PetImages/Dog/1628.jpg a /content/PetImages/Dog/perro7557.jpg
# Se cambió el nombre de /content/PetImages/Dog/12430.jpg a /content/PetImages/Dog/perro7558.jpg
# Se cambió el nombre de /content/PetImages/Dog/9138.jpg a /content/PetImages/Dog/perro7559.jpg
# Se cambió el nombre de /content/PetImages/Dog/4316.jpg a /content/PetImages/Dog/perro7560.jpg
# Se cambió el nombre de /content/PetImages/Dog/249.jpg a /content/PetImages/Dog/perro7561.jpg
# Se cambió el nombre de /content/PetImages/Dog/5461.jpg a /content/PetImages/Dog/perro7562.jpg
# Se cambió el nombre de /content/PetImages/Dog/1449.jpg a /content/PetImages/Dog/perro7563.jpg
# Se cambió el nombre de /content/PetImages/Dog/8292.jpg a /content/PetImages/Dog/perro7564.jpg
# Se cambió el nombre de /content/PetImages/Dog/9274.jpg a /content/PetImages/Dog/perro7565.jpg
# Se cambió el nombre de /content/PetImages/Dog/10799.jpg a /content/PetImages/Dog/perro7566.jpg
# Se cambió el nombre de /content/PetImages/Dog/10569.jpg a /content/PetImages/Dog/perro7567.jpg
# Se cambió el nombre de /content/PetImages/Dog/1940.jpg a /content/PetImages/Dog/perro7568.jpg
# Se cambió el nombre de /content/PetImages/Dog/4732.jpg a /content/PetImages/Dog/perro7569.jpg
# Se cambió el nombre de /content/PetImages/Dog/7664.jpg a /content/PetImages/Dog/perro7570.jpg
# Se cambió el nombre de /content/PetImages/Dog/8384.jpg a /content/PetImages/Dog/perro7571.jpg
# Se cambió el nombre de /content/PetImages/Dog/3658.jpg a /content/PetImages/Dog/perro7572.jpg
# Se cambió el nombre de /content/PetImages/Dog/3133.jpg a /content/PetImages/Dog/perro7573.jpg
# Se cambió el nombre de /content/PetImages/Dog/9581.jpg a /content/PetImages/Dog/perro7574.jpg
# Se cambió el nombre de /content/PetImages/Dog/6373.jpg a /content/PetImages/Dog/perro7575.jpg
# Se cambió el nombre de /content/PetImages/Dog/1033.jpg a /content/PetImages/Dog/perro7576.jpg
# Se cambió el nombre de /content/PetImages/Dog/10795.jpg a /content/PetImages/Dog/perro7577.jpg
# Se cambió el nombre de /content/PetImages/Dog/10677.jpg a /content/PetImages/Dog/perro7578.jpg
# Se cambió el nombre de /content/PetImages/Dog/11998.jpg a /content/PetImages/Dog/perro7579.jpg
# Se cambió el nombre de /content/PetImages/Dog/8949.jpg a /content/PetImages/Dog/perro7580.jpg
# Se cambió el nombre de /content/PetImages/Dog/2816.jpg a /content/PetImages/Dog/perro7581.jpg
# Se cambió el nombre de /content/PetImages/Dog/12141.jpg a /content/PetImages/Dog/perro7582.jpg
# Se cambió el nombre de /content/PetImages/Dog/23.jpg a /content/PetImages/Dog/perro7583.jpg
# Se cambió el nombre de /content/PetImages/Dog/7981.jpg a /content/PetImages/Dog/perro7584.jpg
# Se cambió el nombre de /content/PetImages/Dog/5935.jpg a /content/PetImages/Dog/perro7585.jpg
# Se cambió el nombre de /content/PetImages/Dog/12203.jpg a /content/PetImages/Dog/perro7586.jpg
# Se cambió el nombre de /content/PetImages/Dog/12365.jpg a /content/PetImages/Dog/perro7587.jpg
# Se cambió el nombre de /content/PetImages/Dog/11677.jpg a /content/PetImages/Dog/perro7588.jpg
# Se cambió el nombre de /content/PetImages/Dog/5035.jpg a /content/PetImages/Dog/perro7589.jpg
# Se cambió el nombre de /content/PetImages/Dog/6681.jpg a /content/PetImages/Dog/perro7590.jpg
# Se cambió el nombre de /content/PetImages/Dog/11722.jpg a /content/PetImages/Dog/perro7591.jpg
# Se cambió el nombre de /content/PetImages/Dog/4191.jpg a /content/PetImages/Dog/perro7592.jpg
# Se cambió el nombre de /content/PetImages/Dog/3400.jpg a /content/PetImages/Dog/perro7593.jpg
# Se cambió el nombre de /content/PetImages/Dog/1937.jpg a /content/PetImages/Dog/perro7594.jpg
# Se cambió el nombre de /content/PetImages/Dog/778.jpg a /content/PetImages/Dog/perro7595.jpg
# Se cambió el nombre de /content/PetImages/Dog/6878.jpg a /content/PetImages/Dog/perro7596.jpg
# Se cambió el nombre de /content/PetImages/Dog/8604.jpg a /content/PetImages/Dog/perro7597.jpg
# Se cambió el nombre de /content/PetImages/Dog/7782.jpg a /content/PetImages/Dog/perro7598.jpg
# Se cambió el nombre de /content/PetImages/Dog/10338.jpg a /content/PetImages/Dog/perro7599.jpg
# Se cambió el nombre de /content/PetImages/Dog/6283.jpg a /content/PetImages/Dog/perro7600.jpg
# Se cambió el nombre de /content/PetImages/Dog/8146.jpg a /content/PetImages/Dog/perro7601.jpg
# Se cambió el nombre de /content/PetImages/Dog/8118.jpg a /content/PetImages/Dog/perro7602.jpg
# Se cambió el nombre de /content/PetImages/Dog/11728.jpg a /content/PetImages/Dog/perro7603.jpg
# Se cambió el nombre de /content/PetImages/Dog/7001.jpg a /content/PetImages/Dog/perro7604.jpg
# Se cambió el nombre de /content/PetImages/Dog/10519.jpg a /content/PetImages/Dog/perro7605.jpg
# Se cambió el nombre de /content/PetImages/Dog/8821.jpg a /content/PetImages/Dog/perro7606.jpg
# Se cambió el nombre de /content/PetImages/Dog/5828.jpg a /content/PetImages/Dog/perro7607.jpg
# Se cambió el nombre de /content/PetImages/Dog/3474.jpg a /content/PetImages/Dog/perro7608.jpg
# Se cambió el nombre de /content/PetImages/Dog/11058.jpg a /content/PetImages/Dog/perro7609.jpg
# Se cambió el nombre de /content/PetImages/Dog/8910.jpg a /content/PetImages/Dog/perro7610.jpg
# Se cambió el nombre de /content/PetImages/Dog/1227.jpg a /content/PetImages/Dog/perro7611.jpg
# Se cambió el nombre de /content/PetImages/Dog/4813.jpg a /content/PetImages/Dog/perro7612.jpg
# Se cambió el nombre de /content/PetImages/Dog/1534.jpg a /content/PetImages/Dog/perro7613.jpg
# Se cambió el nombre de /content/PetImages/Dog/11786.jpg a /content/PetImages/Dog/perro7614.jpg
# Se cambió el nombre de /content/PetImages/Dog/2521.jpg a /content/PetImages/Dog/perro7615.jpg
# Se cambió el nombre de /content/PetImages/Dog/1900.jpg a /content/PetImages/Dog/perro7616.jpg
# Se cambió el nombre de /content/PetImages/Dog/2360.jpg a /content/PetImages/Dog/perro7617.jpg
# Se cambió el nombre de /content/PetImages/Dog/10551.jpg a /content/PetImages/Dog/perro7618.jpg
# Se cambió el nombre de /content/PetImages/Dog/1712.jpg a /content/PetImages/Dog/perro7619.jpg
# Se cambió el nombre de /content/PetImages/Dog/7119.jpg a /content/PetImages/Dog/perro7620.jpg
# Se cambió el nombre de /content/PetImages/Dog/12187.jpg a /content/PetImages/Dog/perro7621.jpg
# Se cambió el nombre de /content/PetImages/Dog/10925.jpg a /content/PetImages/Dog/perro7622.jpg
# Se cambió el nombre de /content/PetImages/Dog/10189.jpg a /content/PetImages/Dog/perro7623.jpg
# Se cambió el nombre de /content/PetImages/Dog/11603.jpg a /content/PetImages/Dog/perro7624.jpg
# Se cambió el nombre de /content/PetImages/Dog/2184.jpg a /content/PetImages/Dog/perro7625.jpg
# Se cambió el nombre de /content/PetImages/Dog/2973.jpg a /content/PetImages/Dog/perro7626.jpg
# Se cambió el nombre de /content/PetImages/Dog/9036.jpg a /content/PetImages/Dog/perro7627.jpg
# Se cambió el nombre de /content/PetImages/Dog/3806.jpg a /content/PetImages/Dog/perro7628.jpg
# Se cambió el nombre de /content/PetImages/Dog/6952.jpg a /content/PetImages/Dog/perro7629.jpg
# Se cambió el nombre de /content/PetImages/Dog/6675.jpg a /content/PetImages/Dog/perro7630.jpg
# Se cambió el nombre de /content/PetImages/Dog/6324.jpg a /content/PetImages/Dog/perro7631.jpg
# Se cambió el nombre de /content/PetImages/Dog/8095.jpg a /content/PetImages/Dog/perro7632.jpg
# Se cambió el nombre de /content/PetImages/Dog/4089.jpg a /content/PetImages/Dog/perro7633.jpg
# Se cambió el nombre de /content/PetImages/Dog/2545.jpg a /content/PetImages/Dog/perro7634.jpg
# Se cambió el nombre de /content/PetImages/Dog/1641.jpg a /content/PetImages/Dog/perro7635.jpg
# Se cambió el nombre de /content/PetImages/Dog/375.jpg a /content/PetImages/Dog/perro7636.jpg
# Se cambió el nombre de /content/PetImages/Dog/12159.jpg a /content/PetImages/Dog/perro7637.jpg
# Se cambió el nombre de /content/PetImages/Dog/1557.jpg a /content/PetImages/Dog/perro7638.jpg
# Se cambió el nombre de /content/PetImages/Dog/9235.jpg a /content/PetImages/Dog/perro7639.jpg
# Se cambió el nombre de /content/PetImages/Dog/4733.jpg a /content/PetImages/Dog/perro7640.jpg
# Se cambió el nombre de /content/PetImages/Dog/10919.jpg a /content/PetImages/Dog/perro7641.jpg
# Se cambió el nombre de /content/PetImages/Dog/1699.jpg a /content/PetImages/Dog/perro7642.jpg
# Se cambió el nombre de /content/PetImages/Dog/2872.jpg a /content/PetImages/Dog/perro7643.jpg
# Se cambió el nombre de /content/PetImages/Dog/11641.jpg a /content/PetImages/Dog/perro7644.jpg
# Se cambió el nombre de /content/PetImages/Dog/5236.jpg a /content/PetImages/Dog/perro7645.jpg
# Se cambió el nombre de /content/PetImages/Dog/10093.jpg a /content/PetImages/Dog/perro7646.jpg
# Se cambió el nombre de /content/PetImages/Dog/6178.jpg a /content/PetImages/Dog/perro7647.jpg
# Se cambió el nombre de /content/PetImages/Dog/7220.jpg a /content/PetImages/Dog/perro7648.jpg
# Se cambió el nombre de /content/PetImages/Dog/667.jpg a /content/PetImages/Dog/perro7649.jpg
# Se cambió el nombre de /content/PetImages/Dog/12273.jpg a /content/PetImages/Dog/perro7650.jpg
# Se cambió el nombre de /content/PetImages/Dog/2251.jpg a /content/PetImages/Dog/perro7651.jpg
# Se cambió el nombre de /content/PetImages/Dog/11556.jpg a /content/PetImages/Dog/perro7652.jpg
# Se cambió el nombre de /content/PetImages/Dog/7901.jpg a /content/PetImages/Dog/perro7653.jpg
# Se cambió el nombre de /content/PetImages/Dog/4508.jpg a /content/PetImages/Dog/perro7654.jpg
# Se cambió el nombre de /content/PetImages/Dog/9599.jpg a /content/PetImages/Dog/perro7655.jpg
# Se cambió el nombre de /content/PetImages/Dog/4888.jpg a /content/PetImages/Dog/perro7656.jpg
# Se cambió el nombre de /content/PetImages/Dog/7642.jpg a /content/PetImages/Dog/perro7657.jpg
# Se cambió el nombre de /content/PetImages/Dog/8552.jpg a /content/PetImages/Dog/perro7658.jpg
# Se cambió el nombre de /content/PetImages/Dog/2710.jpg a /content/PetImages/Dog/perro7659.jpg
# Se cambió el nombre de /content/PetImages/Dog/10995.jpg a /content/PetImages/Dog/perro7660.jpg
# Se cambió el nombre de /content/PetImages/Dog/5629.jpg a /content/PetImages/Dog/perro7661.jpg
# Se cambió el nombre de /content/PetImages/Dog/1333.jpg a /content/PetImages/Dog/perro7662.jpg
# Se cambió el nombre de /content/PetImages/Dog/1718.jpg a /content/PetImages/Dog/perro7663.jpg
# Se cambió el nombre de /content/PetImages/Dog/2515.jpg a /content/PetImages/Dog/perro7664.jpg
# Se cambió el nombre de /content/PetImages/Dog/7650.jpg a /content/PetImages/Dog/perro7665.jpg
# Se cambió el nombre de /content/PetImages/Dog/2755.jpg a /content/PetImages/Dog/perro7666.jpg
# Se cambió el nombre de /content/PetImages/Dog/7312.jpg a /content/PetImages/Dog/perro7667.jpg
# Se cambió el nombre de /content/PetImages/Dog/8504.jpg a /content/PetImages/Dog/perro7668.jpg
# Se cambió el nombre de /content/PetImages/Dog/6415.jpg a /content/PetImages/Dog/perro7669.jpg
# Se cambió el nombre de /content/PetImages/Dog/230.jpg a /content/PetImages/Dog/perro7670.jpg
# Se cambió el nombre de /content/PetImages/Dog/10249.jpg a /content/PetImages/Dog/perro7671.jpg
# Se cambió el nombre de /content/PetImages/Dog/8191.jpg a /content/PetImages/Dog/perro7672.jpg
# Se cambió el nombre de /content/PetImages/Dog/5065.jpg a /content/PetImages/Dog/perro7673.jpg
# Se cambió el nombre de /content/PetImages/Dog/4518.jpg a /content/PetImages/Dog/perro7674.jpg
# Se cambió el nombre de /content/PetImages/Dog/11062.jpg a /content/PetImages/Dog/perro7675.jpg
# Se cambió el nombre de /content/PetImages/Dog/7676.jpg a /content/PetImages/Dog/perro7676.jpg
# Se cambió el nombre de /content/PetImages/Dog/2647.jpg a /content/PetImages/Dog/perro7677.jpg
# Se cambió el nombre de /content/PetImages/Dog/2737.jpg a /content/PetImages/Dog/perro7678.jpg
# Se cambió el nombre de /content/PetImages/Dog/9964.jpg a /content/PetImages/Dog/perro7679.jpg
# Se cambió el nombre de /content/PetImages/Dog/2050.jpg a /content/PetImages/Dog/perro7680.jpg
# Se cambió el nombre de /content/PetImages/Dog/9270.jpg a /content/PetImages/Dog/perro7681.jpg
# Se cambió el nombre de /content/PetImages/Dog/6683.jpg a /content/PetImages/Dog/perro7682.jpg
# Se cambió el nombre de /content/PetImages/Dog/7694.jpg a /content/PetImages/Dog/perro7683.jpg
# Se cambió el nombre de /content/PetImages/Dog/5306.jpg a /content/PetImages/Dog/perro7684.jpg
# Se cambió el nombre de /content/PetImages/Dog/10554.jpg a /content/PetImages/Dog/perro7685.jpg
# Se cambió el nombre de /content/PetImages/Dog/5808.jpg a /content/PetImages/Dog/perro7686.jpg
# Se cambió el nombre de /content/PetImages/Dog/186.jpg a /content/PetImages/Dog/perro7687.jpg
# Se cambió el nombre de /content/PetImages/Dog/1111.jpg a /content/PetImages/Dog/perro7688.jpg
# Se cambió el nombre de /content/PetImages/Dog/8555.jpg a /content/PetImages/Dog/perro7689.jpg
# Se cambió el nombre de /content/PetImages/Dog/8436.jpg a /content/PetImages/Dog/perro7690.jpg
# Se cambió el nombre de /content/PetImages/Dog/8755.jpg a /content/PetImages/Dog/perro7691.jpg
# Se cambió el nombre de /content/PetImages/Dog/2828.jpg a /content/PetImages/Dog/perro7692.jpg
# Se cambió el nombre de /content/PetImages/Dog/5473.jpg a /content/PetImages/Dog/perro7693.jpg
# Se cambió el nombre de /content/PetImages/Dog/10822.jpg a /content/PetImages/Dog/perro7694.jpg
# Se cambió el nombre de /content/PetImages/Dog/7134.jpg a /content/PetImages/Dog/perro7695.jpg
# Se cambió el nombre de /content/PetImages/Dog/9899.jpg a /content/PetImages/Dog/perro7696.jpg
# Se cambió el nombre de /content/PetImages/Dog/4568.jpg a /content/PetImages/Dog/perro7697.jpg
# Se cambió el nombre de /content/PetImages/Dog/4057.jpg a /content/PetImages/Dog/perro7698.jpg
# Se cambió el nombre de /content/PetImages/Dog/11044.jpg a /content/PetImages/Dog/perro7699.jpg
# Se cambió el nombre de /content/PetImages/Dog/6261.jpg a /content/PetImages/Dog/perro7700.jpg
# Se cambió el nombre de /content/PetImages/Dog/1964.jpg a /content/PetImages/Dog/perro7701.jpg
# Se cambió el nombre de /content/PetImages/Dog/9850.jpg a /content/PetImages/Dog/perro7702.jpg
# Se cambió el nombre de /content/PetImages/Dog/8003.jpg a /content/PetImages/Dog/perro7703.jpg
# Se cambió el nombre de /content/PetImages/Dog/7051.jpg a /content/PetImages/Dog/perro7704.jpg
# Se cambió el nombre de /content/PetImages/Dog/11740.jpg a /content/PetImages/Dog/perro7705.jpg
# Se cambió el nombre de /content/PetImages/Dog/9063.jpg a /content/PetImages/Dog/perro7706.jpg
# Se cambió el nombre de /content/PetImages/Dog/11833.jpg a /content/PetImages/Dog/perro7707.jpg
# Se cambió el nombre de /content/PetImages/Dog/7164.jpg a /content/PetImages/Dog/perro7708.jpg
# Se cambió el nombre de /content/PetImages/Dog/4999.jpg a /content/PetImages/Dog/perro7709.jpg
# Se cambió el nombre de /content/PetImages/Dog/5077.jpg a /content/PetImages/Dog/perro7710.jpg
# Se cambió el nombre de /content/PetImages/Dog/10235.jpg a /content/PetImages/Dog/perro7711.jpg
# Se cambió el nombre de /content/PetImages/Dog/10269.jpg a /content/PetImages/Dog/perro7712.jpg
# Se cambió el nombre de /content/PetImages/Dog/1500.jpg a /content/PetImages/Dog/perro7713.jpg
# Se cambió el nombre de /content/PetImages/Dog/12064.jpg a /content/PetImages/Dog/perro7714.jpg
# Se cambió el nombre de /content/PetImages/Dog/5582.jpg a /content/PetImages/Dog/perro7715.jpg
# Se cambió el nombre de /content/PetImages/Dog/5165.jpg a /content/PetImages/Dog/perro7716.jpg
# Se cambió el nombre de /content/PetImages/Dog/773.jpg a /content/PetImages/Dog/perro7717.jpg
# Se cambió el nombre de /content/PetImages/Dog/4818.jpg a /content/PetImages/Dog/perro7718.jpg
# Se cambió el nombre de /content/PetImages/Dog/4874.jpg a /content/PetImages/Dog/perro7719.jpg
# Se cambió el nombre de /content/PetImages/Dog/7988.jpg a /content/PetImages/Dog/perro7720.jpg
# Se cambió el nombre de /content/PetImages/Dog/8393.jpg a /content/PetImages/Dog/perro7721.jpg
# Se cambió el nombre de /content/PetImages/Dog/7094.jpg a /content/PetImages/Dog/perro7722.jpg
# Se cambió el nombre de /content/PetImages/Dog/8903.jpg a /content/PetImages/Dog/perro7723.jpg
# Se cambió el nombre de /content/PetImages/Dog/1992.jpg a /content/PetImages/Dog/perro7724.jpg
# Se cambió el nombre de /content/PetImages/Dog/4541.jpg a /content/PetImages/Dog/perro7725.jpg
# Se cambió el nombre de /content/PetImages/Dog/9053.jpg a /content/PetImages/Dog/perro7726.jpg
# Se cambió el nombre de /content/PetImages/Dog/1159.jpg a /content/PetImages/Dog/perro7727.jpg
# Se cambió el nombre de /content/PetImages/Dog/4408.jpg a /content/PetImages/Dog/perro7728.jpg
# Se cambió el nombre de /content/PetImages/Dog/7419.jpg a /content/PetImages/Dog/perro7729.jpg
# Se cambió el nombre de /content/PetImages/Dog/296.jpg a /content/PetImages/Dog/perro7730.jpg
# Se cambió el nombre de /content/PetImages/Dog/1874.jpg a /content/PetImages/Dog/perro7731.jpg
# Se cambió el nombre de /content/PetImages/Dog/6860.jpg a /content/PetImages/Dog/perro7732.jpg
# Se cambió el nombre de /content/PetImages/Dog/4112.jpg a /content/PetImages/Dog/perro7733.jpg
# Se cambió el nombre de /content/PetImages/Dog/2147.jpg a /content/PetImages/Dog/perro7734.jpg
# Se cambió el nombre de /content/PetImages/Dog/5549.jpg a /content/PetImages/Dog/perro7735.jpg
# Se cambió el nombre de /content/PetImages/Dog/1356.jpg a /content/PetImages/Dog/perro7736.jpg
# Se cambió el nombre de /content/PetImages/Dog/654.jpg a /content/PetImages/Dog/perro7737.jpg
# Se cambió el nombre de /content/PetImages/Dog/10725.jpg a /content/PetImages/Dog/perro7738.jpg
# Se cambió el nombre de /content/PetImages/Dog/7045.jpg a /content/PetImages/Dog/perro7739.jpg
# Se cambió el nombre de /content/PetImages/Dog/5153.jpg a /content/PetImages/Dog/perro7740.jpg
# Se cambió el nombre de /content/PetImages/Dog/7407.jpg a /content/PetImages/Dog/perro7741.jpg
# Se cambió el nombre de /content/PetImages/Dog/4895.jpg a /content/PetImages/Dog/perro7742.jpg
# Se cambió el nombre de /content/PetImages/Dog/1851.jpg a /content/PetImages/Dog/perro7743.jpg
# Se cambió el nombre de /content/PetImages/Dog/8817.jpg a /content/PetImages/Dog/perro7744.jpg
# Se cambió el nombre de /content/PetImages/Dog/9968.jpg a /content/PetImages/Dog/perro7745.jpg
# Se cambió el nombre de /content/PetImages/Dog/1368.jpg a /content/PetImages/Dog/perro7746.jpg
# Se cambió el nombre de /content/PetImages/Dog/6846.jpg a /content/PetImages/Dog/perro7747.jpg
# Se cambió el nombre de /content/PetImages/Dog/10414.jpg a /content/PetImages/Dog/perro7748.jpg
# Se cambió el nombre de /content/PetImages/Dog/7002.jpg a /content/PetImages/Dog/perro7749.jpg
# Se cambió el nombre de /content/PetImages/Dog/4909.jpg a /content/PetImages/Dog/perro7750.jpg
# Se cambió el nombre de /content/PetImages/Dog/4100.jpg a /content/PetImages/Dog/perro7751.jpg
# Se cambió el nombre de /content/PetImages/Dog/5327.jpg a /content/PetImages/Dog/perro7752.jpg
# Se cambió el nombre de /content/PetImages/Dog/10154.jpg a /content/PetImages/Dog/perro7753.jpg
# Se cambió el nombre de /content/PetImages/Dog/10351.jpg a /content/PetImages/Dog/perro7754.jpg
# Se cambió el nombre de /content/PetImages/Dog/161.jpg a /content/PetImages/Dog/perro7755.jpg
# Se cambió el nombre de /content/PetImages/Dog/221.jpg a /content/PetImages/Dog/perro7756.jpg
# Se cambió el nombre de /content/PetImages/Dog/11527.jpg a /content/PetImages/Dog/perro7757.jpg
# Se cambió el nombre de /content/PetImages/Dog/4103.jpg a /content/PetImages/Dog/perro7758.jpg
# Se cambió el nombre de /content/PetImages/Dog/3057.jpg a /content/PetImages/Dog/perro7759.jpg
# Se cambió el nombre de /content/PetImages/Dog/5823.jpg a /content/PetImages/Dog/perro7760.jpg
# Se cambió el nombre de /content/PetImages/Dog/6745.jpg a /content/PetImages/Dog/perro7761.jpg
# Se cambió el nombre de /content/PetImages/Dog/10590.jpg a /content/PetImages/Dog/perro7762.jpg
# Se cambió el nombre de /content/PetImages/Dog/8454.jpg a /content/PetImages/Dog/perro7763.jpg
# Se cambió el nombre de /content/PetImages/Dog/5007.jpg a /content/PetImages/Dog/perro7764.jpg
# Se cambió el nombre de /content/PetImages/Dog/8867.jpg a /content/PetImages/Dog/perro7765.jpg
# Se cambió el nombre de /content/PetImages/Dog/2074.jpg a /content/PetImages/Dog/perro7766.jpg
# Se cambió el nombre de /content/PetImages/Dog/2117.jpg a /content/PetImages/Dog/perro7767.jpg
# Se cambió el nombre de /content/PetImages/Dog/6228.jpg a /content/PetImages/Dog/perro7768.jpg
# Se cambió el nombre de /content/PetImages/Dog/954.jpg a /content/PetImages/Dog/perro7769.jpg
# Se cambió el nombre de /content/PetImages/Dog/4302.jpg a /content/PetImages/Dog/perro7770.jpg
# Se cambió el nombre de /content/PetImages/Dog/12330.jpg a /content/PetImages/Dog/perro7771.jpg
# Se cambió el nombre de /content/PetImages/Dog/4390.jpg a /content/PetImages/Dog/perro7772.jpg
# Se cambió el nombre de /content/PetImages/Dog/4458.jpg a /content/PetImages/Dog/perro7773.jpg
# Se cambió el nombre de /content/PetImages/Dog/4469.jpg a /content/PetImages/Dog/perro7774.jpg
# Se cambió el nombre de /content/PetImages/Dog/724.jpg a /content/PetImages/Dog/perro7775.jpg
# Se cambió el nombre de /content/PetImages/Dog/11233.jpg a /content/PetImages/Dog/perro7776.jpg
# Se cambió el nombre de /content/PetImages/Dog/1543.jpg a /content/PetImages/Dog/perro7777.jpg
# Se cambió el nombre de /content/PetImages/Dog/12254.jpg a /content/PetImages/Dog/perro7778.jpg
# Se cambió el nombre de /content/PetImages/Dog/6606.jpg a /content/PetImages/Dog/perro7779.jpg
# Se cambió el nombre de /content/PetImages/Dog/11001.jpg a /content/PetImages/Dog/perro7780.jpg
# Se cambió el nombre de /content/PetImages/Dog/9759.jpg a /content/PetImages/Dog/perro7781.jpg
# Se cambió el nombre de /content/PetImages/Dog/10620.jpg a /content/PetImages/Dog/perro7782.jpg
# Se cambió el nombre de /content/PetImages/Dog/551.jpg a /content/PetImages/Dog/perro7783.jpg
# Se cambió el nombre de /content/PetImages/Dog/1397.jpg a /content/PetImages/Dog/perro7784.jpg
# Se cambió el nombre de /content/PetImages/Dog/7830.jpg a /content/PetImages/Dog/perro7785.jpg
# Se cambió el nombre de /content/PetImages/Dog/5110.jpg a /content/PetImages/Dog/perro7786.jpg
# Se cambió el nombre de /content/PetImages/Dog/10105.jpg a /content/PetImages/Dog/perro7787.jpg
# Se cambió el nombre de /content/PetImages/Dog/8100.jpg a /content/PetImages/Dog/perro7788.jpg
# Se cambió el nombre de /content/PetImages/Dog/2247.jpg a /content/PetImages/Dog/perro7789.jpg
# Se cambió el nombre de /content/PetImages/Dog/8390.jpg a /content/PetImages/Dog/perro7790.jpg
# Se cambió el nombre de /content/PetImages/Dog/4878.jpg a /content/PetImages/Dog/perro7791.jpg
# Se cambió el nombre de /content/PetImages/Dog/3532.jpg a /content/PetImages/Dog/perro7792.jpg
# Se cambió el nombre de /content/PetImages/Dog/9695.jpg a /content/PetImages/Dog/perro7793.jpg
# Se cambió el nombre de /content/PetImages/Dog/4298.jpg a /content/PetImages/Dog/perro7794.jpg
# Se cambió el nombre de /content/PetImages/Dog/1345.jpg a /content/PetImages/Dog/perro7795.jpg
# Se cambió el nombre de /content/PetImages/Dog/10873.jpg a /content/PetImages/Dog/perro7796.jpg
# Se cambió el nombre de /content/PetImages/Dog/8408.jpg a /content/PetImages/Dog/perro7797.jpg
# Se cambió el nombre de /content/PetImages/Dog/11161.jpg a /content/PetImages/Dog/perro7798.jpg
# Se cambió el nombre de /content/PetImages/Dog/10787.jpg a /content/PetImages/Dog/perro7799.jpg
# Se cambió el nombre de /content/PetImages/Dog/7725.jpg a /content/PetImages/Dog/perro7800.jpg
# Se cambió el nombre de /content/PetImages/Dog/4931.jpg a /content/PetImages/Dog/perro7801.jpg
# Se cambió el nombre de /content/PetImages/Dog/651.jpg a /content/PetImages/Dog/perro7802.jpg
# Se cambió el nombre de /content/PetImages/Dog/6461.jpg a /content/PetImages/Dog/perro7803.jpg
# Se cambió el nombre de /content/PetImages/Dog/405.jpg a /content/PetImages/Dog/perro7804.jpg
# Se cambió el nombre de /content/PetImages/Dog/3363.jpg a /content/PetImages/Dog/perro7805.jpg
# Se cambió el nombre de /content/PetImages/Dog/4864.jpg a /content/PetImages/Dog/perro7806.jpg
# Se cambió el nombre de /content/PetImages/Dog/6066.jpg a /content/PetImages/Dog/perro7807.jpg
# Se cambió el nombre de /content/PetImages/Dog/11545.jpg a /content/PetImages/Dog/perro7808.jpg
# Se cambió el nombre de /content/PetImages/Dog/5718.jpg a /content/PetImages/Dog/perro7809.jpg
# Se cambió el nombre de /content/PetImages/Dog/8426.jpg a /content/PetImages/Dog/perro7810.jpg
# Se cambió el nombre de /content/PetImages/Dog/11817.jpg a /content/PetImages/Dog/perro7811.jpg
# Se cambió el nombre de /content/PetImages/Dog/2136.jpg a /content/PetImages/Dog/perro7812.jpg
# Se cambió el nombre de /content/PetImages/Dog/10288.jpg a /content/PetImages/Dog/perro7813.jpg
# Se cambió el nombre de /content/PetImages/Dog/10177.jpg a /content/PetImages/Dog/perro7814.jpg
# Se cambió el nombre de /content/PetImages/Dog/818.jpg a /content/PetImages/Dog/perro7815.jpg
# Se cambió el nombre de /content/PetImages/Dog/10416.jpg a /content/PetImages/Dog/perro7816.jpg
# Se cambió el nombre de /content/PetImages/Dog/383.jpg a /content/PetImages/Dog/perro7817.jpg
# Se cambió el nombre de /content/PetImages/Dog/9893.jpg a /content/PetImages/Dog/perro7818.jpg
# Se cambió el nombre de /content/PetImages/Dog/9305.jpg a /content/PetImages/Dog/perro7819.jpg
# Se cambió el nombre de /content/PetImages/Dog/3131.jpg a /content/PetImages/Dog/perro7820.jpg
# Se cambió el nombre de /content/PetImages/Dog/3045.jpg a /content/PetImages/Dog/perro7821.jpg
# Se cambió el nombre de /content/PetImages/Dog/8349.jpg a /content/PetImages/Dog/perro7822.jpg
# Se cambió el nombre de /content/PetImages/Dog/7457.jpg a /content/PetImages/Dog/perro7823.jpg
# Se cambió el nombre de /content/PetImages/Dog/9557.jpg a /content/PetImages/Dog/perro7824.jpg
# Se cambió el nombre de /content/PetImages/Dog/3172.jpg a /content/PetImages/Dog/perro7825.jpg
# Se cambió el nombre de /content/PetImages/Dog/4583.jpg a /content/PetImages/Dog/perro7826.jpg
# Se cambió el nombre de /content/PetImages/Dog/1740.jpg a /content/PetImages/Dog/perro7827.jpg
# Se cambió el nombre de /content/PetImages/Dog/4053.jpg a /content/PetImages/Dog/perro7828.jpg
# Se cambió el nombre de /content/PetImages/Dog/10270.jpg a /content/PetImages/Dog/perro7829.jpg
# Se cambió el nombre de /content/PetImages/Dog/6083.jpg a /content/PetImages/Dog/perro7830.jpg
# Se cambió el nombre de /content/PetImages/Dog/8087.jpg a /content/PetImages/Dog/perro7831.jpg
# Se cambió el nombre de /content/PetImages/Dog/359.jpg a /content/PetImages/Dog/perro7832.jpg
# Se cambió el nombre de /content/PetImages/Dog/7589.jpg a /content/PetImages/Dog/perro7833.jpg
# Se cambió el nombre de /content/PetImages/Dog/6103.jpg a /content/PetImages/Dog/perro7834.jpg
# Se cambió el nombre de /content/PetImages/Dog/6482.jpg a /content/PetImages/Dog/perro7835.jpg
# Se cambió el nombre de /content/PetImages/Dog/11465.jpg a /content/PetImages/Dog/perro7836.jpg
# Se cambió el nombre de /content/PetImages/Dog/9345.jpg a /content/PetImages/Dog/perro7837.jpg
# Se cambió el nombre de /content/PetImages/Dog/11644.jpg a /content/PetImages/Dog/perro7838.jpg
# Se cambió el nombre de /content/PetImages/Dog/1.jpg a /content/PetImages/Dog/perro7839.jpg
# Se cambió el nombre de /content/PetImages/Dog/11818.jpg a /content/PetImages/Dog/perro7840.jpg
# Se cambió el nombre de /content/PetImages/Dog/5199.jpg a /content/PetImages/Dog/perro7841.jpg
# Se cambió el nombre de /content/PetImages/Dog/4740.jpg a /content/PetImages/Dog/perro7842.jpg
# Se cambió el nombre de /content/PetImages/Dog/6193.jpg a /content/PetImages/Dog/perro7843.jpg
# Se cambió el nombre de /content/PetImages/Dog/6491.jpg a /content/PetImages/Dog/perro7844.jpg
# Se cambió el nombre de /content/PetImages/Dog/1634.jpg a /content/PetImages/Dog/perro7845.jpg
# Se cambió el nombre de /content/PetImages/Dog/11253.jpg a /content/PetImages/Dog/perro7846.jpg
# Se cambió el nombre de /content/PetImages/Dog/8840.jpg a /content/PetImages/Dog/perro7847.jpg
# Se cambió el nombre de /content/PetImages/Dog/2863.jpg a /content/PetImages/Dog/perro7848.jpg
# Se cambió el nombre de /content/PetImages/Dog/767.jpg a /content/PetImages/Dog/perro7849.jpg
# Se cambió el nombre de /content/PetImages/Dog/7266.jpg a /content/PetImages/Dog/perro7850.jpg
# Se cambió el nombre de /content/PetImages/Dog/3115.jpg a /content/PetImages/Dog/perro7851.jpg
# Se cambió el nombre de /content/PetImages/Dog/94.jpg a /content/PetImages/Dog/perro7852.jpg
# Se cambió el nombre de /content/PetImages/Dog/2088.jpg a /content/PetImages/Dog/perro7853.jpg
# Se cambió el nombre de /content/PetImages/Dog/4257.jpg a /content/PetImages/Dog/perro7854.jpg
# Se cambió el nombre de /content/PetImages/Dog/12319.jpg a /content/PetImages/Dog/perro7855.jpg
# Se cambió el nombre de /content/PetImages/Dog/7593.jpg a /content/PetImages/Dog/perro7856.jpg
# Se cambió el nombre de /content/PetImages/Dog/12314.jpg a /content/PetImages/Dog/perro7857.jpg
# Se cambió el nombre de /content/PetImages/Dog/10211.jpg a /content/PetImages/Dog/perro7858.jpg
# Se cambió el nombre de /content/PetImages/Dog/5999.jpg a /content/PetImages/Dog/perro7859.jpg
# Se cambió el nombre de /content/PetImages/Dog/76.jpg a /content/PetImages/Dog/perro7860.jpg
# Se cambió el nombre de /content/PetImages/Dog/5197.jpg a /content/PetImages/Dog/perro7861.jpg
# Se cambió el nombre de /content/PetImages/Dog/1226.jpg a /content/PetImages/Dog/perro7862.jpg
# Se cambió el nombre de /content/PetImages/Dog/8027.jpg a /content/PetImages/Dog/perro7863.jpg
# Se cambió el nombre de /content/PetImages/Dog/195.jpg a /content/PetImages/Dog/perro7864.jpg
# Se cambió el nombre de /content/PetImages/Dog/11830.jpg a /content/PetImages/Dog/perro7865.jpg
# Se cambió el nombre de /content/PetImages/Dog/4877.jpg a /content/PetImages/Dog/perro7866.jpg
# Se cambió el nombre de /content/PetImages/Dog/4656.jpg a /content/PetImages/Dog/perro7867.jpg
# Se cambió el nombre de /content/PetImages/Dog/6365.jpg a /content/PetImages/Dog/perro7868.jpg
# Se cambió el nombre de /content/PetImages/Dog/10015.jpg a /content/PetImages/Dog/perro7869.jpg
# Se cambió el nombre de /content/PetImages/Dog/7524.jpg a /content/PetImages/Dog/perro7870.jpg
# Se cambió el nombre de /content/PetImages/Dog/7536.jpg a /content/PetImages/Dog/perro7871.jpg
# Se cambió el nombre de /content/PetImages/Dog/5688.jpg a /content/PetImages/Dog/perro7872.jpg
# Se cambió el nombre de /content/PetImages/Dog/11173.jpg a /content/PetImages/Dog/perro7873.jpg
# Se cambió el nombre de /content/PetImages/Dog/6791.jpg a /content/PetImages/Dog/perro7874.jpg
# Se cambió el nombre de /content/PetImages/Dog/11078.jpg a /content/PetImages/Dog/perro7875.jpg
# Se cambió el nombre de /content/PetImages/Dog/6401.jpg a /content/PetImages/Dog/perro7876.jpg
# Se cambió el nombre de /content/PetImages/Dog/619.jpg a /content/PetImages/Dog/perro7877.jpg
# Se cambió el nombre de /content/PetImages/Dog/9954.jpg a /content/PetImages/Dog/perro7878.jpg
# Se cambió el nombre de /content/PetImages/Dog/11377.jpg a /content/PetImages/Dog/perro7879.jpg
# Se cambió el nombre de /content/PetImages/Dog/998.jpg a /content/PetImages/Dog/perro7880.jpg
# Se cambió el nombre de /content/PetImages/Dog/8283.jpg a /content/PetImages/Dog/perro7881.jpg
# Se cambió el nombre de /content/PetImages/Dog/1614.jpg a /content/PetImages/Dog/perro7882.jpg
# Se cambió el nombre de /content/PetImages/Dog/8630.jpg a /content/PetImages/Dog/perro7883.jpg
# Se cambió el nombre de /content/PetImages/Dog/4355.jpg a /content/PetImages/Dog/perro7884.jpg
# Se cambió el nombre de /content/PetImages/Dog/7084.jpg a /content/PetImages/Dog/perro7885.jpg
# Se cambió el nombre de /content/PetImages/Dog/7288.jpg a /content/PetImages/Dog/perro7886.jpg
# Se cambió el nombre de /content/PetImages/Dog/7109.jpg a /content/PetImages/Dog/perro7887.jpg
# Se cambió el nombre de /content/PetImages/Dog/2814.jpg a /content/PetImages/Dog/perro7888.jpg
# Se cambió el nombre de /content/PetImages/Dog/5518.jpg a /content/PetImages/Dog/perro7889.jpg
# Se cambió el nombre de /content/PetImages/Dog/5442.jpg a /content/PetImages/Dog/perro7890.jpg
# Se cambió el nombre de /content/PetImages/Dog/11272.jpg a /content/PetImages/Dog/perro7891.jpg
# Se cambió el nombre de /content/PetImages/Dog/5315.jpg a /content/PetImages/Dog/perro7892.jpg
# Se cambió el nombre de /content/PetImages/Dog/2464.jpg a /content/PetImages/Dog/perro7893.jpg
# Se cambió el nombre de /content/PetImages/Dog/9815.jpg a /content/PetImages/Dog/perro7894.jpg
# Se cambió el nombre de /content/PetImages/Dog/9765.jpg a /content/PetImages/Dog/perro7895.jpg
# Se cambió el nombre de /content/PetImages/Dog/6275.jpg a /content/PetImages/Dog/perro7896.jpg
# Se cambió el nombre de /content/PetImages/Dog/9147.jpg a /content/PetImages/Dog/perro7897.jpg
# Se cambió el nombre de /content/PetImages/Dog/12149.jpg a /content/PetImages/Dog/perro7898.jpg
# Se cambió el nombre de /content/PetImages/Dog/3118.jpg a /content/PetImages/Dog/perro7899.jpg
# Se cambió el nombre de /content/PetImages/Dog/463.jpg a /content/PetImages/Dog/perro7900.jpg
# Se cambió el nombre de /content/PetImages/Dog/2843.jpg a /content/PetImages/Dog/perro7901.jpg
# Se cambió el nombre de /content/PetImages/Dog/1106.jpg a /content/PetImages/Dog/perro7902.jpg
# Se cambió el nombre de /content/PetImages/Dog/9463.jpg a /content/PetImages/Dog/perro7903.jpg
# Se cambió el nombre de /content/PetImages/Dog/11478.jpg a /content/PetImages/Dog/perro7904.jpg
# Se cambió el nombre de /content/PetImages/Dog/8004.jpg a /content/PetImages/Dog/perro7905.jpg
# Se cambió el nombre de /content/PetImages/Dog/7442.jpg a /content/PetImages/Dog/perro7906.jpg
# Se cambió el nombre de /content/PetImages/Dog/8226.jpg a /content/PetImages/Dog/perro7907.jpg
# Se cambió el nombre de /content/PetImages/Dog/7229.jpg a /content/PetImages/Dog/perro7908.jpg
# Se cambió el nombre de /content/PetImages/Dog/7969.jpg a /content/PetImages/Dog/perro7909.jpg
# Se cambió el nombre de /content/PetImages/Dog/2403.jpg a /content/PetImages/Dog/perro7910.jpg
# Se cambió el nombre de /content/PetImages/Dog/4778.jpg a /content/PetImages/Dog/perro7911.jpg
# Se cambió el nombre de /content/PetImages/Dog/2075.jpg a /content/PetImages/Dog/perro7912.jpg
# Se cambió el nombre de /content/PetImages/Dog/1488.jpg a /content/PetImages/Dog/perro7913.jpg
# Se cambió el nombre de /content/PetImages/Dog/3285.jpg a /content/PetImages/Dog/perro7914.jpg
# Se cambió el nombre de /content/PetImages/Dog/2171.jpg a /content/PetImages/Dog/perro7915.jpg
# Se cambió el nombre de /content/PetImages/Dog/3812.jpg a /content/PetImages/Dog/perro7916.jpg
# Se cambió el nombre de /content/PetImages/Dog/1458.jpg a /content/PetImages/Dog/perro7917.jpg
# Se cambió el nombre de /content/PetImages/Dog/4064.jpg a /content/PetImages/Dog/perro7918.jpg
# Se cambió el nombre de /content/PetImages/Dog/8399.jpg a /content/PetImages/Dog/perro7919.jpg
# Se cambió el nombre de /content/PetImages/Dog/12052.jpg a /content/PetImages/Dog/perro7920.jpg
# Se cambió el nombre de /content/PetImages/Dog/1298.jpg a /content/PetImages/Dog/perro7921.jpg
# Se cambió el nombre de /content/PetImages/Dog/9165.jpg a /content/PetImages/Dog/perro7922.jpg
# Se cambió el nombre de /content/PetImages/Dog/2971.jpg a /content/PetImages/Dog/perro7923.jpg
# Se cambió el nombre de /content/PetImages/Dog/4034.jpg a /content/PetImages/Dog/perro7924.jpg
# Se cambió el nombre de /content/PetImages/Dog/8907.jpg a /content/PetImages/Dog/perro7925.jpg
# Se cambió el nombre de /content/PetImages/Dog/5071.jpg a /content/PetImages/Dog/perro7926.jpg
# Se cambió el nombre de /content/PetImages/Dog/675.jpg a /content/PetImages/Dog/perro7927.jpg
# Se cambió el nombre de /content/PetImages/Dog/627.jpg a /content/PetImages/Dog/perro7928.jpg
# Se cambió el nombre de /content/PetImages/Dog/3050.jpg a /content/PetImages/Dog/perro7929.jpg
# Se cambió el nombre de /content/PetImages/Dog/4330.jpg a /content/PetImages/Dog/perro7930.jpg
# Se cambió el nombre de /content/PetImages/Dog/8280.jpg a /content/PetImages/Dog/perro7931.jpg
# Se cambió el nombre de /content/PetImages/Dog/6348.jpg a /content/PetImages/Dog/perro7932.jpg
# Se cambió el nombre de /content/PetImages/Dog/9531.jpg a /content/PetImages/Dog/perro7933.jpg
# Se cambió el nombre de /content/PetImages/Dog/4086.jpg a /content/PetImages/Dog/perro7934.jpg
# Se cambió el nombre de /content/PetImages/Dog/2083.jpg a /content/PetImages/Dog/perro7935.jpg
# Se cambió el nombre de /content/PetImages/Dog/8714.jpg a /content/PetImages/Dog/perro7936.jpg
# Se cambió el nombre de /content/PetImages/Dog/8603.jpg a /content/PetImages/Dog/perro7937.jpg
# Se cambió el nombre de /content/PetImages/Dog/10130.jpg a /content/PetImages/Dog/perro7938.jpg
# Se cambió el nombre de /content/PetImages/Dog/12300.jpg a /content/PetImages/Dog/perro7939.jpg
# Se cambió el nombre de /content/PetImages/Dog/11430.jpg a /content/PetImages/Dog/perro7940.jpg
# Se cambió el nombre de /content/PetImages/Dog/8839.jpg a /content/PetImages/Dog/perro7941.jpg
# Se cambió el nombre de /content/PetImages/Dog/6693.jpg a /content/PetImages/Dog/perro7942.jpg
# Se cambió el nombre de /content/PetImages/Dog/11504.jpg a /content/PetImages/Dog/perro7943.jpg
# Se cambió el nombre de /content/PetImages/Dog/3591.jpg a /content/PetImages/Dog/perro7944.jpg
# Se cambió el nombre de /content/PetImages/Dog/6262.jpg a /content/PetImages/Dog/perro7945.jpg
# Se cambió el nombre de /content/PetImages/Dog/205.jpg a /content/PetImages/Dog/perro7946.jpg
# Se cambió el nombre de /content/PetImages/Dog/3983.jpg a /content/PetImages/Dog/perro7947.jpg
# Se cambió el nombre de /content/PetImages/Dog/3419.jpg a /content/PetImages/Dog/perro7948.jpg
# Se cambió el nombre de /content/PetImages/Dog/5405.jpg a /content/PetImages/Dog/perro7949.jpg
# Se cambió el nombre de /content/PetImages/Dog/9752.jpg a /content/PetImages/Dog/perro7950.jpg
# Se cambió el nombre de /content/PetImages/Dog/11600.jpg a /content/PetImages/Dog/perro7951.jpg
# Se cambió el nombre de /content/PetImages/Dog/10830.jpg a /content/PetImages/Dog/perro7952.jpg
# Se cambió el nombre de /content/PetImages/Dog/4369.jpg a /content/PetImages/Dog/perro7953.jpg
# Se cambió el nombre de /content/PetImages/Dog/4602.jpg a /content/PetImages/Dog/perro7954.jpg
# Se cambió el nombre de /content/PetImages/Dog/2191.jpg a /content/PetImages/Dog/perro7955.jpg
# Se cambió el nombre de /content/PetImages/Dog/4587.jpg a /content/PetImages/Dog/perro7956.jpg
# Se cambió el nombre de /content/PetImages/Dog/12427.jpg a /content/PetImages/Dog/perro7957.jpg
# Se cambió el nombre de /content/PetImages/Dog/8378.jpg a /content/PetImages/Dog/perro7958.jpg
# Se cambió el nombre de /content/PetImages/Dog/11220.jpg a /content/PetImages/Dog/perro7959.jpg
# Se cambió el nombre de /content/PetImages/Dog/2044.jpg a /content/PetImages/Dog/perro7960.jpg
# Se cambió el nombre de /content/PetImages/Dog/4727.jpg a /content/PetImages/Dog/perro7961.jpg
# Se cambió el nombre de /content/PetImages/Dog/11040.jpg a /content/PetImages/Dog/perro7962.jpg
# Se cambió el nombre de /content/PetImages/Dog/1104.jpg a /content/PetImages/Dog/perro7963.jpg
# Se cambió el nombre de /content/PetImages/Dog/12491.jpg a /content/PetImages/Dog/perro7964.jpg
# Se cambió el nombre de /content/PetImages/Dog/9121.jpg a /content/PetImages/Dog/perro7965.jpg
# Se cambió el nombre de /content/PetImages/Dog/2882.jpg a /content/PetImages/Dog/perro7966.jpg
# Se cambió el nombre de /content/PetImages/Dog/8682.jpg a /content/PetImages/Dog/perro7967.jpg
# Se cambió el nombre de /content/PetImages/Dog/4697.jpg a /content/PetImages/Dog/perro7968.jpg
# Se cambió el nombre de /content/PetImages/Dog/1800.jpg a /content/PetImages/Dog/perro7969.jpg
# Se cambió el nombre de /content/PetImages/Dog/2544.jpg a /content/PetImages/Dog/perro7970.jpg
# Se cambió el nombre de /content/PetImages/Dog/6798.jpg a /content/PetImages/Dog/perro7971.jpg
# Se cambió el nombre de /content/PetImages/Dog/7904.jpg a /content/PetImages/Dog/perro7972.jpg
# Se cambió el nombre de /content/PetImages/Dog/631.jpg a /content/PetImages/Dog/perro7973.jpg
# Se cambió el nombre de /content/PetImages/Dog/11859.jpg a /content/PetImages/Dog/perro7974.jpg
# Se cambió el nombre de /content/PetImages/Dog/2552.jpg a /content/PetImages/Dog/perro7975.jpg
# Se cambió el nombre de /content/PetImages/Dog/8484.jpg a /content/PetImages/Dog/perro7976.jpg
# Se cambió el nombre de /content/PetImages/Dog/4540.jpg a /content/PetImages/Dog/perro7977.jpg
# Se cambió el nombre de /content/PetImages/Dog/4956.jpg a /content/PetImages/Dog/perro7978.jpg
# Se cambió el nombre de /content/PetImages/Dog/4013.jpg a /content/PetImages/Dog/perro7979.jpg
# Se cambió el nombre de /content/PetImages/Dog/10201.jpg a /content/PetImages/Dog/perro7980.jpg
# Se cambió el nombre de /content/PetImages/Dog/11338.jpg a /content/PetImages/Dog/perro7981.jpg
# Se cambió el nombre de /content/PetImages/Dog/8210.jpg a /content/PetImages/Dog/perro7982.jpg
# Se cambió el nombre de /content/PetImages/Dog/6187.jpg a /content/PetImages/Dog/perro7983.jpg
# Se cambió el nombre de /content/PetImages/Dog/8461.jpg a /content/PetImages/Dog/perro7984.jpg
# Se cambió el nombre de /content/PetImages/Dog/8549.jpg a /content/PetImages/Dog/perro7985.jpg
# Se cambió el nombre de /content/PetImages/Dog/5763.jpg a /content/PetImages/Dog/perro7986.jpg
# Se cambió el nombre de /content/PetImages/Dog/3941.jpg a /content/PetImages/Dog/perro7987.jpg
# Se cambió el nombre de /content/PetImages/Dog/4679.jpg a /content/PetImages/Dog/perro7988.jpg
# Se cambió el nombre de /content/PetImages/Dog/10704.jpg a /content/PetImages/Dog/perro7989.jpg
# Se cambió el nombre de /content/PetImages/Dog/10507.jpg a /content/PetImages/Dog/perro7990.jpg
# Se cambió el nombre de /content/PetImages/Dog/11468.jpg a /content/PetImages/Dog/perro7991.jpg
# Se cambió el nombre de /content/PetImages/Dog/7247.jpg a /content/PetImages/Dog/perro7992.jpg
# Se cambió el nombre de /content/PetImages/Dog/8379.jpg a /content/PetImages/Dog/perro7993.jpg
# Se cambió el nombre de /content/PetImages/Dog/167.jpg a /content/PetImages/Dog/perro7994.jpg
# Se cambió el nombre de /content/PetImages/Dog/9841.jpg a /content/PetImages/Dog/perro7995.jpg
# Se cambió el nombre de /content/PetImages/Dog/5902.jpg a /content/PetImages/Dog/perro7996.jpg
# Se cambió el nombre de /content/PetImages/Dog/3101.jpg a /content/PetImages/Dog/perro7997.jpg
# Se cambió el nombre de /content/PetImages/Dog/3177.jpg a /content/PetImages/Dog/perro7998.jpg
# Se cambió el nombre de /content/PetImages/Dog/11293.jpg a /content/PetImages/Dog/perro7999.jpg
# Se cambió el nombre de /content/PetImages/Dog/1752.jpg a /content/PetImages/Dog/perro8000.jpg
# Se cambió el nombre de /content/PetImages/Dog/880.jpg a /content/PetImages/Dog/perro8001.jpg
# Se cambió el nombre de /content/PetImages/Dog/1965.jpg a /content/PetImages/Dog/perro8002.jpg
# Se cambió el nombre de /content/PetImages/Dog/8657.jpg a /content/PetImages/Dog/perro8003.jpg
# Se cambió el nombre de /content/PetImages/Dog/5020.jpg a /content/PetImages/Dog/perro8004.jpg
# Se cambió el nombre de /content/PetImages/Dog/11201.jpg a /content/PetImages/Dog/perro8005.jpg
# Se cambió el nombre de /content/PetImages/Dog/6963.jpg a /content/PetImages/Dog/perro8006.jpg
# Se cambió el nombre de /content/PetImages/Dog/3170.jpg a /content/PetImages/Dog/perro8007.jpg
# Se cambió el nombre de /content/PetImages/Dog/3686.jpg a /content/PetImages/Dog/perro8008.jpg
# Se cambió el nombre de /content/PetImages/Dog/5960.jpg a /content/PetImages/Dog/perro8009.jpg
# Se cambió el nombre de /content/PetImages/Dog/9362.jpg a /content/PetImages/Dog/perro8010.jpg
# Se cambió el nombre de /content/PetImages/Dog/4491.jpg a /content/PetImages/Dog/perro8011.jpg
# ...
# Se cambió el nombre de /content/PetImages/Dog/4449.jpg a /content/PetImages/Dog/perro12337.jpg
# Se cambió el nombre de /content/PetImages/Dog/4752.jpg a /content/PetImages/Dog/perro12338.jpg
# Se cambió el nombre de /content/PetImages/Dog/12017.jpg a /content/PetImages/Dog/perro12339.jpg
# Se cambió el nombre de /content/PetImages/Dog/8190.jpg a /content/PetImages/Dog/perro12340.jpg
# Se cambió el nombre de /content/PetImages/Dog/10091.jpg a /content/PetImages/Dog/perro12341.jpg
# Se cambió el nombre de /content/PetImages/Dog/5898.jpg a /content/PetImages/Dog/perro12342.jpg
# Se cambió el nombre de /content/PetImages/Dog/4614.jpg a /content/PetImages/Dog/perro12343.jpg
# Se cambió el nombre de /content/PetImages/Dog/7388.jpg a /content/PetImages/Dog/perro12344.jpg
# Se cambió el nombre de /content/PetImages/Dog/6298.jpg a /content/PetImages/Dog/perro12345.jpg
# Se cambió el nombre de /content/PetImages/Dog/5288.jpg a /content/PetImages/Dog/perro12346.jpg
# Se cambió el nombre de /content/PetImages/Dog/1498.jpg a /content/PetImages/Dog/perro12347.jpg
# Se cambió el nombre de /content/PetImages/Dog/11456.jpg a /content/PetImages/Dog/perro12348.jpg
# Se cambió el nombre de /content/PetImages/Dog/9167.jpg a /content/PetImages/Dog/perro12349.jpg
# Se cambió el nombre de /content/PetImages/Dog/4238.jpg a /content/PetImages/Dog/perro12350.jpg
# Se cambió el nombre de /content/PetImages/Dog/2196.jpg a /content/PetImages/Dog/perro12351.jpg
# Se cambió el nombre de /content/PetImages/Dog/11410.jpg a /content/PetImages/Dog/perro12352.jpg
# Se cambió el nombre de /content/PetImages/Dog/7794.jpg a /content/PetImages/Dog/perro12353.jpg
# Se cambió el nombre de /content/PetImages/Dog/964.jpg a /content/PetImages/Dog/perro12354.jpg
# Se cambió el nombre de /content/PetImages/Dog/2743.jpg a /content/PetImages/Dog/perro12355.jpg
# Se cambió el nombre de /content/PetImages/Dog/9108.jpg a /content/PetImages/Dog/perro12356.jpg
# Se cambió el nombre de /content/PetImages/Dog/10237.jpg a /content/PetImages/Dog/perro12357.jpg
# Se cambió el nombre de /content/PetImages/Dog/2626.jpg a /content/PetImages/Dog/perro12358.jpg
# Se cambió el nombre de /content/PetImages/Dog/1439.jpg a /content/PetImages/Dog/perro12359.jpg
# Se cambió el nombre de /content/PetImages/Dog/7745.jpg a /content/PetImages/Dog/perro12360.jpg
# Se cambió el nombre de /content/PetImages/Dog/2246.jpg a /content/PetImages/Dog/perro12361.jpg
# Se cambió el nombre de /content/PetImages/Dog/726.jpg a /content/PetImages/Dog/perro12362.jpg
# Se cambió el nombre de /content/PetImages/Dog/11013.jpg a /content/PetImages/Dog/perro12363.jpg
# Se cambió el nombre de /content/PetImages/Dog/8329.jpg a /content/PetImages/Dog/perro12364.jpg
# Se cambió el nombre de /content/PetImages/Dog/4724.jpg a /content/PetImages/Dog/perro12365.jpg
# Se cambió el nombre de /content/PetImages/Dog/2385.jpg a /content/PetImages/Dog/perro12366.jpg
# Se cambió el nombre de /content/PetImages/Dog/7532.jpg a /content/PetImages/Dog/perro12367.jpg
# Se cambió el nombre de /content/PetImages/Dog/5389.jpg a /content/PetImages/Dog/perro12368.jpg
# Se cambió el nombre de /content/PetImages/Dog/2453.jpg a /content/PetImages/Dog/perro12369.jpg
# Se cambió el nombre de /content/PetImages/Dog/3557.jpg a /content/PetImages/Dog/perro12370.jpg
# Se cambió el nombre de /content/PetImages/Dog/2664.jpg a /content/PetImages/Dog/perro12371.jpg
# Se cambió el nombre de /content/PetImages/Dog/9713.jpg a /content/PetImages/Dog/perro12372.jpg
# Se cambió el nombre de /content/PetImages/Dog/4278.jpg a /content/PetImages/Dog/perro12373.jpg
# Se cambió el nombre de /content/PetImages/Dog/3490.jpg a /content/PetImages/Dog/perro12374.jpg
# Se cambió el nombre de /content/PetImages/Dog/6510.jpg a /content/PetImages/Dog/perro12375.jpg
# Se cambió el nombre de /content/PetImages/Dog/3859.jpg a /content/PetImages/Dog/perro12376.jpg
# Se cambió el nombre de /content/PetImages/Dog/8804.jpg a /content/PetImages/Dog/perro12377.jpg
# Se cambió el nombre de /content/PetImages/Dog/3927.jpg a /content/PetImages/Dog/perro12378.jpg
# Se cambió el nombre de /content/PetImages/Dog/10877.jpg a /content/PetImages/Dog/perro12379.jpg
# Se cambió el nombre de /content/PetImages/Dog/10908.jpg a /content/PetImages/Dog/perro12380.jpg
# Se cambió el nombre de /content/PetImages/Dog/1317.jpg a /content/PetImages/Dog/perro12381.jpg
# Se cambió el nombre de /content/PetImages/Dog/4148.jpg a /content/PetImages/Dog/perro12382.jpg
# Se cambió el nombre de /content/PetImages/Dog/10061.jpg a /content/PetImages/Dog/perro12383.jpg
# Se cambió el nombre de /content/PetImages/Dog/4973.jpg a /content/PetImages/Dog/perro12384.jpg
# Se cambió el nombre de /content/PetImages/Dog/5137.jpg a /content/PetImages/Dog/perro12385.jpg
# Se cambió el nombre de /content/PetImages/Dog/5420.jpg a /content/PetImages/Dog/perro12386.jpg
# Se cambió el nombre de /content/PetImages/Dog/4001.jpg a /content/PetImages/Dog/perro12387.jpg
# Se cambió el nombre de /content/PetImages/Dog/10784.jpg a /content/PetImages/Dog/perro12388.jpg
# Se cambió el nombre de /content/PetImages/Dog/9790.jpg a /content/PetImages/Dog/perro12389.jpg
# Se cambió el nombre de /content/PetImages/Dog/7347.jpg a /content/PetImages/Dog/perro12390.jpg
# Se cambió el nombre de /content/PetImages/Dog/4887.jpg a /content/PetImages/Dog/perro12391.jpg
# Se cambió el nombre de /content/PetImages/Dog/4422.jpg a /content/PetImages/Dog/perro12392.jpg
# Se cambió el nombre de /content/PetImages/Dog/11046.jpg a /content/PetImages/Dog/perro12393.jpg
# Se cambió el nombre de /content/PetImages/Dog/8033.jpg a /content/PetImages/Dog/perro12394.jpg
# Se cambió el nombre de /content/PetImages/Dog/3829.jpg a /content/PetImages/Dog/perro12395.jpg
# Se cambió el nombre de /content/PetImages/Dog/1626.jpg a /content/PetImages/Dog/perro12396.jpg
# Se cambió el nombre de /content/PetImages/Dog/4689.jpg a /content/PetImages/Dog/perro12397.jpg
# Se cambió el nombre de /content/PetImages/Dog/2909.jpg a /content/PetImages/Dog/perro12398.jpg
# Se cambió el nombre de /content/PetImages/Dog/4285.jpg a /content/PetImages/Dog/perro12399.jpg
# Se cambió el nombre de /content/PetImages/Dog/2857.jpg a /content/PetImages/Dog/perro12400.jpg
# Se cambió el nombre de /content/PetImages/Dog/9621.jpg a /content/PetImages/Dog/perro12401.jpg
# Se cambió el nombre de /content/PetImages/Dog/3767.jpg a /content/PetImages/Dog/perro12402.jpg
# Se cambió el nombre de /content/PetImages/Dog/2893.jpg a /content/PetImages/Dog/perro12403.jpg
# Se cambió el nombre de /content/PetImages/Dog/4399.jpg a /content/PetImages/Dog/perro12404.jpg
# Se cambió el nombre de /content/PetImages/Dog/5057.jpg a /content/PetImages/Dog/perro12405.jpg
# Se cambió el nombre de /content/PetImages/Dog/6456.jpg a /content/PetImages/Dog/perro12406.jpg
# Se cambió el nombre de /content/PetImages/Dog/1184.jpg a /content/PetImages/Dog/perro12407.jpg
# Se cambió el nombre de /content/PetImages/Dog/1840.jpg a /content/PetImages/Dog/perro12408.jpg
# Se cambió el nombre de /content/PetImages/Dog/2597.jpg a /content/PetImages/Dog/perro12409.jpg
# Se cambió el nombre de /content/PetImages/Dog/7818.jpg a /content/PetImages/Dog/perro12410.jpg
# Se cambió el nombre de /content/PetImages/Dog/893.jpg a /content/PetImages/Dog/perro12411.jpg
# Se cambió el nombre de /content/PetImages/Dog/10706.jpg a /content/PetImages/Dog/perro12412.jpg
# Se cambió el nombre de /content/PetImages/Dog/11447.jpg a /content/PetImages/Dog/perro12413.jpg
# Se cambió el nombre de /content/PetImages/Dog/9445.jpg a /content/PetImages/Dog/perro12414.jpg
# Se cambió el nombre de /content/PetImages/Dog/11375.jpg a /content/PetImages/Dog/perro12415.jpg
# Se cambió el nombre de /content/PetImages/Dog/7339.jpg a /content/PetImages/Dog/perro12416.jpg
# Se cambió el nombre de /content/PetImages/Dog/4111.jpg a /content/PetImages/Dog/perro12417.jpg
# Se cambió el nombre de /content/PetImages/Dog/1161.jpg a /content/PetImages/Dog/perro12418.jpg
# Se cambió el nombre de /content/PetImages/Dog/5139.jpg a /content/PetImages/Dog/perro12419.jpg
# Se cambió el nombre de /content/PetImages/Dog/9175.jpg a /content/PetImages/Dog/perro12420.jpg
# Se cambió el nombre de /content/PetImages/Dog/3636.jpg a /content/PetImages/Dog/perro12421.jpg
# Se cambió el nombre de /content/PetImages/Dog/8373.jpg a /content/PetImages/Dog/perro12422.jpg
# Se cambió el nombre de /content/PetImages/Dog/985.jpg a /content/PetImages/Dog/perro12423.jpg
# Se cambió el nombre de /content/PetImages/Dog/5240.jpg a /content/PetImages/Dog/perro12424.jpg
# Se cambió el nombre de /content/PetImages/Dog/1727.jpg a /content/PetImages/Dog/perro12425.jpg
# Se cambió el nombre de /content/PetImages/Dog/6431.jpg a /content/PetImages/Dog/perro12426.jpg
# Se cambió el nombre de /content/PetImages/Dog/11575.jpg a /content/PetImages/Dog/perro12427.jpg
# Se cambió el nombre de /content/PetImages/Dog/10758.jpg a /content/PetImages/Dog/perro12428.jpg
# Se cambió el nombre de /content/PetImages/Dog/7354.jpg a /content/PetImages/Dog/perro12429.jpg
# Se cambió el nombre de /content/PetImages/Dog/492.jpg a /content/PetImages/Dog/perro12430.jpg
# Se cambió el nombre de /content/PetImages/Dog/9403.jpg a /content/PetImages/Dog/perro12431.jpg
# Se cambió el nombre de /content/PetImages/Dog/10076.jpg a /content/PetImages/Dog/perro12432.jpg
# Se cambió el nombre de /content/PetImages/Dog/10312.jpg a /content/PetImages/Dog/perro12433.jpg
# Se cambió el nombre de /content/PetImages/Dog/2593.jpg a /content/PetImages/Dog/perro12434.jpg
# Se cambió el nombre de /content/PetImages/Dog/523.jpg a /content/PetImages/Dog/perro12435.jpg
# Se cambió el nombre de /content/PetImages/Dog/10220.jpg a /content/PetImages/Dog/perro12436.jpg
# Se cambió el nombre de /content/PetImages/Dog/11760.jpg a /content/PetImages/Dog/perro12437.jpg
# Se cambió el nombre de /content/PetImages/Dog/7855.jpg a /content/PetImages/Dog/perro12438.jpg
# Se cambió el nombre de /content/PetImages/Dog/5595.jpg a /content/PetImages/Dog/perro12439.jpg
# Se cambió el nombre de /content/PetImages/Dog/75.jpg a /content/PetImages/Dog/perro12440.jpg
# Se cambió el nombre de /content/PetImages/Dog/8002.jpg a /content/PetImages/Dog/perro12441.jpg
# Se cambió el nombre de /content/PetImages/Dog/4162.jpg a /content/PetImages/Dog/perro12442.jpg
# Se cambió el nombre de /content/PetImages/Dog/11345.jpg a /content/PetImages/Dog/perro12443.jpg
# Se cambió el nombre de /content/PetImages/Dog/3870.jpg a /content/PetImages/Dog/perro12444.jpg
# Se cambió el nombre de /content/PetImages/Dog/12190.jpg a /content/PetImages/Dog/perro12445.jpg
# Se cambió el nombre de /content/PetImages/Dog/3208.jpg a /content/PetImages/Dog/perro12446.jpg
# Se cambió el nombre de /content/PetImages/Dog/2804.jpg a /content/PetImages/Dog/perro12447.jpg
# Se cambió el nombre de /content/PetImages/Dog/5117.jpg a /content/PetImages/Dog/perro12448.jpg
# Se cambió el nombre de /content/PetImages/Dog/4496.jpg a /content/PetImages/Dog/perro12449.jpg
# Se cambió el nombre de /content/PetImages/Dog/10834.jpg a /content/PetImages/Dog/perro12450.jpg
# Se cambió el nombre de /content/PetImages/Dog/11366.jpg a /content/PetImages/Dog/perro12451.jpg
# Se cambió el nombre de /content/PetImages/Dog/11544.jpg a /content/PetImages/Dog/perro12452.jpg
# Se cambió el nombre de /content/PetImages/Dog/4024.jpg a /content/PetImages/Dog/perro12453.jpg
# Se cambió el nombre de /content/PetImages/Dog/11376.jpg a /content/PetImages/Dog/perro12454.jpg
# Se cambió el nombre de /content/PetImages/Dog/7874.jpg a /content/PetImages/Dog/perro12455.jpg
# Se cambió el nombre de /content/PetImages/Dog/11080.jpg a /content/PetImages/Dog/perro12456.jpg
# Se cambió el nombre de /content/PetImages/Dog/9086.jpg a /content/PetImages/Dog/perro12457.jpg
# Se cambió el nombre de /content/PetImages/Dog/6295.jpg a /content/PetImages/Dog/perro12458.jpg
# Se cambió el nombre de /content/PetImages/Dog/8024.jpg a /content/PetImages/Dog/perro12459.jpg
# Se cambió el nombre de /content/PetImages/Dog/11359.jpg a /content/PetImages/Dog/perro12460.jpg
# Se cambió el nombre de /content/PetImages/Dog/2606.jpg a /content/PetImages/Dog/perro12461.jpg
# Se cambió el nombre de /content/PetImages/Dog/7778.jpg a /content/PetImages/Dog/perro12462.jpg
# Se cambió el nombre de /content/PetImages/Dog/7657.jpg a /content/PetImages/Dog/perro12463.jpg
# Se cambió el nombre de /content/PetImages/Dog/3554.jpg a /content/PetImages/Dog/perro12464.jpg
# Se cambió el nombre de /content/PetImages/Dog/7977.jpg a /content/PetImages/Dog/perro12465.jpg
# Se cambió el nombre de /content/PetImages/Dog/8863.jpg a /content/PetImages/Dog/perro12466.jpg
# Se cambió el nombre de /content/PetImages/Dog/1349.jpg a /content/PetImages/Dog/perro12467.jpg
# Se cambió el nombre de /content/PetImages/Dog/3435.jpg a /content/PetImages/Dog/perro12468.jpg
# Se cambió el nombre de /content/PetImages/Dog/7391.jpg a /content/PetImages/Dog/perro12469.jpg
# Se cambió el nombre de /content/PetImages/Dog/2944.jpg a /content/PetImages/Dog/perro12470.jpg
# Se cambió el nombre de /content/PetImages/Dog/108.jpg a /content/PetImages/Dog/perro12471.jpg
# Se cambió el nombre de /content/PetImages/Dog/881.jpg a /content/PetImages/Dog/perro12472.jpg
# Se cambió el nombre de /content/PetImages/Dog/4943.jpg a /content/PetImages/Dog/perro12473.jpg
# Se cambió el nombre de /content/PetImages/Dog/8152.jpg a /content/PetImages/Dog/perro12474.jpg
# Se cambió el nombre de /content/PetImages/Dog/1974.jpg a /content/PetImages/Dog/perro12475.jpg
# Se cambió el nombre de /content/PetImages/Dog/10757.jpg a /content/PetImages/Dog/perro12476.jpg
# Se cambió el nombre de /content/PetImages/Dog/11658.jpg a /content/PetImages/Dog/perro12477.jpg
# Se cambió el nombre de /content/PetImages/Dog/2086.jpg a /content/PetImages/Dog/perro12478.jpg
# Se cambió el nombre de /content/PetImages/Dog/3449.jpg a /content/PetImages/Dog/perro12479.jpg
# Se cambió el nombre de /content/PetImages/Dog/698.jpg a /content/PetImages/Dog/perro12480.jpg
# Se cambió el nombre de /content/PetImages/Dog/165.jpg a /content/PetImages/Dog/perro12481.jpg
# Se cambió el nombre de /content/PetImages/Dog/2219.jpg a /content/PetImages/Dog/perro12482.jpg
# Se cambió el nombre de /content/PetImages/Dog/720.jpg a /content/PetImages/Dog/perro12483.jpg
# Se cambió el nombre de /content/PetImages/Dog/4610.jpg a /content/PetImages/Dog/perro12484.jpg
# Se cambió el nombre de /content/PetImages/Dog/3588.jpg a /content/PetImages/Dog/perro12485.jpg
# Se cambió el nombre de /content/PetImages/Dog/2742.jpg a /content/PetImages/Dog/perro12486.jpg
# Se cambió el nombre de /content/PetImages/Dog/6890.jpg a /content/PetImages/Dog/perro12487.jpg
# Se cambió el nombre de /content/PetImages/Dog/3495.jpg a /content/PetImages/Dog/perro12488.jpg
# Se cambió el nombre de /content/PetImages/Dog/10292.jpg a /content/PetImages/Dog/perro12489.jpg
# Se cambió el nombre de /content/PetImages/Dog/3123.jpg a /content/PetImages/Dog/perro12490.jpg
# Se cambió el nombre de /content/PetImages/Dog/511.jpg a /content/PetImages/Dog/perro12491.jpg
# Se cambió el nombre de /content/PetImages/Dog/10597.jpg a /content/PetImages/Dog/perro12492.jpg
# Se cambió el nombre de /content/PetImages/Dog/12001.jpg a /content/PetImages/Dog/perro12493.jpg
# Se cambió el nombre de /content/PetImages/Dog/11289.jpg a /content/PetImages/Dog/perro12494.jpg
# Se cambió el nombre de /content/PetImages/Dog/6190.jpg a /content/PetImages/Dog/perro12495.jpg
# Se cambió el nombre de /content/PetImages/Dog/7464.jpg a /content/PetImages/Dog/perro12496.jpg
# Se cambió el nombre de /content/PetImages/Dog/6478.jpg a /content/PetImages/Dog/perro12497.jpg
# Se cambió el nombre de /content/PetImages/Dog/1096.jpg a /content/PetImages/Dog/perro12498.jpg
# Se cambió el nombre de /content/PetImages/Dog/6786.jpg a /content/PetImages/Dog/perro12499.jpg
# Se cambió el nombre de /content/PetImages/Dog/787.jpg a /content/PetImages/Dog/perro12500.jpg
# Archivo '/content/PetImages/Cat/gato9510.jpg' eliminado.
# Archivo '/content/PetImages/Dog/perro10608.jpg' eliminado.
# /usr/local/lib/python3.10/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Se ah validado todas las imagenes
# Csv Creado
# la clase gato tiene :12499 elementos
# la clase perro tiene :12499 elementos

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import numpy as np
import sklearn
import cv2
from PIL import Image


class MiDataSet(Dataset):

  def __init__(self,csv_file, transform=None):


     self.data=pd.read_csv(csv_file)

     self.x=self.data["path"]
     self.y=self.data["etiqueta"]

     self.transform=transform

     self.samples=self.data["path"].shape[0]


  def __getitem__(self,id):

    rut_imagen=self.x[id]
    imagen=cv2.imread(rut_imagen)
    etiqueta=self.y[id]


    if imagen is None:
      pillow_image = Image.open(rut_imagen)
      numpy_image = np.array(pillow_image)
      imagen=cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)


    imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)


    if self.transform:
      imagen_rgb = self.transform(imagen_rgb)

    return imagen_rgb,etiqueta


  def __len__(self):
   return self.samples

# %%
#@markdown # *3) ** Separacion dos archivos difentes para entrenamietno y prueba(OBLIGATORIO)

from sklearn.model_selection import train_test_split

misdatos=pd.read_csv("/content/Data_set.csv")
# Separo mis datos en entrenamiento y test

etiquetas=misdatos["etiqueta"]
datos_entrenamiento, datos_evaluacion = train_test_split(misdatos, test_size=0.3, random_state=42,stratify=etiquetas)


# Guardar los dos conjuntos en archivos CSV separados
datos_entrenamiento.to_csv("/content/datos_entrenamiento.csv", index=False)
datos_evaluacion.to_csv("/content/datos_evaluacion.csv", index=False)

# %%
#@markdown # *2) ** Mostrar 20 muestras(Opcional)
import matplotlib.pyplot as plt
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from PIL import Image


# Definir transformaciones
transformaciones = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((100, 100))
])

# Crear dataset y DataLoader
muestra = MiDataSet("/content/datos_entrenamiento.csv", transformaciones)
data_muestra = DataLoader(muestra, batch_size=20, shuffle=True)

# Obtener el primer lote
primer_lote = next(iter(data_muestra))
tensor_imagenes, tensor_etiquetas = primer_lote

# Mapeo de etiquetas numéricas a etiquetas de texto
mapeo_etiquetas = {0: 'gato', 1: 'perro'}
etiquetas_texto = [mapeo_etiquetas[item.item()] for item in tensor_etiquetas]

# Crear una figura y subgráficos
fig, axs = plt.subplots(4, 5, figsize=(20, 20))

# Iterar sobre las imágenes del lote
for i in range(4):
    for j in range(5):
        idx = i * 5 + j
        imagen = tensor_imagenes[idx].permute(1, 2, 0)
        etiqueta_texto = etiquetas_texto[idx]

        # Mostrar la imagen en el subgráfico correspondiente
        axs[i, j].imshow(imagen)
        axs[i, j].set_title(etiqueta_texto)
        axs[i, j].axis('off')

plt.show()

# %%
import sklearn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset

transformaciones = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    transforms.Resize((100, 100),antialias=True)
])


mis_datos_entrenamiento=MiDataSet("/content/datos_entrenamiento.csv",transform=transformaciones)

mis_datos_test=MiDataSet("/content/datos_evaluacion.csv",transform=transformaciones)


data_por_lote_entrenamiento=DataLoader(mis_datos_entrenamiento,batch_size=100,shuffle=True)

data_por_por_lote_test=DataLoader(mis_datos_test,batch_size=100,shuffle=True)

# %%
import torch.nn as nn
import torch.nn.functional as F



class RedConvolucional(nn.Module):

   def __init__(self):
    super(RedConvolucional,self).__init__()

#Red convolulcional

    self.conv1=nn.Conv2d(in_channels=3,out_channels=32,kernel_size=3, stride=1)

    self.conv2=nn.Conv2d(in_channels=32,out_channels=40,kernel_size=3, stride=2)
    self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2)

    self.conv3=nn.Conv2d(in_channels=40,out_channels=48,kernel_size=3, stride=2)

    self.flatten=nn.Flatten()

#Red fully conected o multicapa convecional

    self.capa_oculta1=nn.Linear(11*11*48,500)
    self.capa_oculta2=nn.Linear(500,400)
    self.capa_salida=nn.Linear(400,2)


   def forward(self,x):
    #Capa convolucionales
     x=self.conv1(x)
     x=F.relu(x)

     x=self.conv2(x)
     x=F.relu(x)
     x=self.maxpool1(x)

     x=self.conv3(x)
     x=F.relu(x)

     x=self.flatten(x)

#Capa fully conected
     x=self.capa_oculta1(x)
     x=F.relu(x)
     x=self.capa_oculta2(x)
     x=F.relu(x)

     x=self.capa_salida(x)
     x=F.softmax(x,dim=1)
     return x

# %%
import torch
import torch.optim as optim
import pandas as pd
import matplotlib.pyplot as plt

if torch.cuda.is_available():
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")
#funcion clasificador:
def clasificador(y_pred_test):
    max_indices = torch.argmax(y_pred_test, dim=1)
    return max_indices

#funcion acutity:
def accurity(y_test, y_real):
    correctos = torch.eq(y_test, y_real).sum().item()
    return correctos / len(y_test)


# Solo para re entrenar
# state_dict = torch.load('/content/modelo_gatoperro2.pt')
# ModeloRC.load_state_dict(state_dict)
# ModeloRC=ModeloRC.to(device)


def EntrenamientoCNN(modelo,optimisador,criterio,epocas,datos_loader_train,datos_loader_eval):

 df=pd.DataFrame(columns=["accuracy","loss","epoch"])

 if torch.cuda.is_available():
    print("CUDA está disponible.")
    device = torch.device("cuda")
 else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")

 modelo.to(device)
 for epoch in range(epocas):

    total_train_loss = 0.0
    num_train_batches = len(datos_loader_train)
    modelo.train()

    for i, (xi, yi) in enumerate(datos_loader_train):
        xi, yi = xi.to(device), yi.to(device)
        y_predict = modelo(xi)
        loss = criterio(y_predict, yi)
        optimisador.zero_grad()
        loss.backward()
        optimisador.step()
        optimisador.zero_grad()
        total_train_loss += loss.item()

    modelo.eval()
    with torch.no_grad():
        total_test_accuracy = 0.0
        num_test_batches = len(datos_loader_eval)

        for i, (xi, yi) in enumerate(datos_loader_eval):
            xi, yi = xi.to(device), yi.to(device)
            y_predict_test = modelo(xi)
            y_predic_test_clasificado = clasificador(y_predict_test)
            Precision = accurity(y_predic_test_clasificado, yi)
            total_test_accuracy += Precision

    avg_test_accuracy = total_test_accuracy / num_test_batches
    avg_train_loss = total_train_loss / num_train_batches

    fila={"accuracy":avg_test_accuracy,"loss":avg_train_loss,"epoch":epoch}
    #df=df.append(fila, ignore_index=True)
    df = pd.concat([df, pd.DataFrame([fila])], ignore_index=True)

    print(f'Epoca[{epoch + 1}], Perdida: {avg_train_loss:.4f}, Accuracy:{avg_test_accuracy:.4f}')

 plt.plot(df["epoch"],df["accuracy"],label="Accurity",color='b')
 plt.plot(df["epoch"],df["loss"],label="Loss",color='r')
 plt.title('Loss vs Accuracy')
 plt.legend()
 plt.show()

ModeloRC=RedConvolucional()
optimizer=optim.Adam(ModeloRC.parameters(),lr=0.001)
criterio=nn.CrossEntropyLoss()
epochs=8
EntrenamientoCNN(ModeloRC,optimizer,criterio,epochs,data_por_lote_entrenamiento,data_por_por_lote_test)

torch.save(ModeloRC.state_dict(), 'modelo_gatoperro.pt')
# Out:
# CUDA está disponible.
# CUDA está disponible.
# Epoca[1], Perdida: 0.6350, Accuracy:0.6899
# Epoca[2], Perdida: 0.5736, Accuracy:0.7245
# Epoca[3], Perdida: 0.5386, Accuracy:0.7615
# Epoca[4], Perdida: 0.5036, Accuracy:0.7745
# Epoca[5], Perdida: 0.4754, Accuracy:0.7856
# Epoca[6], Perdida: 0.4540, Accuracy:0.7547
# Epoca[7], Perdida: 0.4349, Accuracy:0.7741
# Epoca[8], Perdida: 0.4127, Accuracy:0.7864

# %%
import cv2
from google.colab import files
import torch
import matplotlib.pyplot as plt
from torchvision import transforms
if torch.cuda.is_available():
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")

# Obtener el nombre del archivo y cargar la imagen

img_path = "/content/descarga.jpg"
imagen=cv2.imread(img_path)
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

plt.imshow(imagen_rgb)
plt.show()

transformacion = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((100, 100)),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])

])

imagen_tensor = transformacion(imagen_rgb)
imagen_tensor=imagen_tensor.to(device)



# Carga los pesos del modelo entrenado
ModeloRC= RedConvolucional()
state_dict = torch.load('/content/modelo_gatoperro.pt')

# Load the state dictionary into the model
ModeloRC.load_state_dict(state_dict)
ModeloRC = ModeloRC.to('cuda')
print(ModeloRC)
# Asegúrate de poner el modelo en modo de evaluación si es necesario

ModeloRC.eval()
with torch.no_grad():
  predicciones = ModeloRC(imagen_tensor.unsqueeze(0))

  # Obtener la clase predicha (índice de la probabilidad más alta)
  print(predicciones)
  print(clasificador(predicciones))
# Out:
# CUDA está disponible.
# RedConvolucional(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 40, kernel_size=(3, 3), stride=(2, 2))
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(40, 48, kernel_size=(3, 3), stride=(2, 2))
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (capa_oculta1): Linear(in_features=5808, out_features=500, bias=True)
#   (capa_oculta2): Linear(in_features=500, out_features=400, bias=True)
#   (capa_salida): Linear(in_features=400, out_features=2, bias=True)
# )
# tensor([[0.0090, 0.9910]], device='cuda:0')
# tensor([1], device='cuda:0')

# %%
# Assuming ModeloRC is an instance of your RedConvolucional model
ModeloRC = RedConvolucional()

import matplotlib.pyplot as plt
import numpy as np
def visualize_conv_layer_weights(layer, cmap='viridis'):
    weights = layer.weight.data.cpu().numpy()
    num_filters = weights.shape[0]

    # Determine the number of rows and columns for subplots
    rows = int(np.sqrt(num_filters))
    cols = num_filters // rows + 1

    # Visualize the weights of each filter
    for i in range(num_filters):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(weights[i, 0], cmap=cmap)
        plt.axis('off')

    plt.show()

# Load the state dictionary into the model
state_dict = torch.load('/content/modelo_gatoperro.pt')
ModeloRC.load_state_dict(state_dict)
ModeloRC = ModeloRC.to('cuda')

# Visualize the weights of each convolutional layer

visualize_conv_layer_weights(ModeloRC.conv3)# poner que capa quiers visuzlar
