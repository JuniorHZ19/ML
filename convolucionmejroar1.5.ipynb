# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/ML/blob/main/convolucionmejroar1.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio

# %%
#@markdown # *1) ** Descargando DataSet  de perros y gatos(OBLIGATORIO)
import zipfile

nombre_zip="data_set_dogcat.zip"

directorio_destino="/content/"

# !gdown --id 19u9sy2053Ds739lyYSJut6S_k54trLnd -O {nombre_zip}

with zipfile.ZipFile(nombre_zip, 'r') as zip_ref:
    zip_ref.extractall(directorio_destino)
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=19u9sy2053Ds739lyYSJut6S_k54trLnd
# To: /content/data_set_dogcat.zip
# 100% 826M/826M [00:16<00:00, 50.1MB/s]

# %%
#@markdown # *0.5) **Arreglo dataset poner secucias archvios y eliminar no imagnees
import os

# Ruta de tu directorio
directorio = "/content/PetImages/Dog"

# Extensiones permitidas
extensiones_permitidas = {".jpg", ".jpeg", ".png"}

# Recorre el directorio
for root, dirs, files in os.walk(directorio):
    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")

#Cambiar nombre de cada archivo de la carpeta secuecnialmente


lista_archivo = os.listdir(directorio)
subfijo="perro"
# Iterar sobre los archivos y cambiarles el nombre
for i, archivo in enumerate(lista_archivo, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorio, archivo)
    ruta_nueva = os.path.join(directorio, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)

    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Se cambió el nombre de /content/PetImages/Dog/perro_3963.jpg a /content/PetImages/Dog/perro7501.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7300.jpg a /content/PetImages/Dog/perro7502.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4200.jpg a /content/PetImages/Dog/perro7503.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5030.jpg a /content/PetImages/Dog/perro7504.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6224.jpg a /content/PetImages/Dog/perro7505.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8125.jpg a /content/PetImages/Dog/perro7506.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9518.jpg a /content/PetImages/Dog/perro7507.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10123.jpg a /content/PetImages/Dog/perro7508.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11263.jpg a /content/PetImages/Dog/perro7509.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5216.jpg a /content/PetImages/Dog/perro7510.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3092.jpg a /content/PetImages/Dog/perro7511.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12120.jpg a /content/PetImages/Dog/perro7512.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9048.jpg a /content/PetImages/Dog/perro7513.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_141.jpg a /content/PetImages/Dog/perro7514.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12250.jpg a /content/PetImages/Dog/perro7515.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7332.jpg a /content/PetImages/Dog/perro7516.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11465.jpg a /content/PetImages/Dog/perro7517.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4533.jpg a /content/PetImages/Dog/perro7518.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12193.jpg a /content/PetImages/Dog/perro7519.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9765.jpg a /content/PetImages/Dog/perro7520.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4317.jpg a /content/PetImages/Dog/perro7521.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3969.jpg a /content/PetImages/Dog/perro7522.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8134.jpg a /content/PetImages/Dog/perro7523.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5350.jpg a /content/PetImages/Dog/perro7524.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11179.jpg a /content/PetImages/Dog/perro7525.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5670.jpg a /content/PetImages/Dog/perro7526.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7427.jpg a /content/PetImages/Dog/perro7527.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3818.jpg a /content/PetImages/Dog/perro7528.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6566.jpg a /content/PetImages/Dog/perro7529.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9329.jpg a /content/PetImages/Dog/perro7530.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3636.jpg a /content/PetImages/Dog/perro7531.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10343.jpg a /content/PetImages/Dog/perro7532.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9129.jpg a /content/PetImages/Dog/perro7533.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6761.jpg a /content/PetImages/Dog/perro7534.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2386.jpg a /content/PetImages/Dog/perro7535.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7485.jpg a /content/PetImages/Dog/perro7536.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4547.jpg a /content/PetImages/Dog/perro7537.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11684.jpg a /content/PetImages/Dog/perro7538.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3015.jpg a /content/PetImages/Dog/perro7539.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1416.jpg a /content/PetImages/Dog/perro7540.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10210.jpg a /content/PetImages/Dog/perro7541.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7257.jpg a /content/PetImages/Dog/perro7542.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6232.jpg a /content/PetImages/Dog/perro7543.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_673.jpg a /content/PetImages/Dog/perro7544.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5202.jpg a /content/PetImages/Dog/perro7545.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10594.jpg a /content/PetImages/Dog/perro7546.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8891.jpg a /content/PetImages/Dog/perro7547.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1356.jpg a /content/PetImages/Dog/perro7548.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9651.jpg a /content/PetImages/Dog/perro7549.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1456.jpg a /content/PetImages/Dog/perro7550.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5522.jpg a /content/PetImages/Dog/perro7551.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12437.jpg a /content/PetImages/Dog/perro7552.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1377.jpg a /content/PetImages/Dog/perro7553.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1176.jpg a /content/PetImages/Dog/perro7554.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9625.jpg a /content/PetImages/Dog/perro7555.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5562.jpg a /content/PetImages/Dog/perro7556.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10638.jpg a /content/PetImages/Dog/perro7557.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3627.jpg a /content/PetImages/Dog/perro7558.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10568.jpg a /content/PetImages/Dog/perro7559.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7823.jpg a /content/PetImages/Dog/perro7560.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8835.jpg a /content/PetImages/Dog/perro7561.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5597.jpg a /content/PetImages/Dog/perro7562.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6977.jpg a /content/PetImages/Dog/perro7563.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1698.jpg a /content/PetImages/Dog/perro7564.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1370.jpg a /content/PetImages/Dog/perro7565.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1978.jpg a /content/PetImages/Dog/perro7566.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8627.jpg a /content/PetImages/Dog/perro7567.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7454.jpg a /content/PetImages/Dog/perro7568.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9770.jpg a /content/PetImages/Dog/perro7569.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_905.jpg a /content/PetImages/Dog/perro7570.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12369.jpg a /content/PetImages/Dog/perro7571.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_769.jpg a /content/PetImages/Dog/perro7572.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5943.jpg a /content/PetImages/Dog/perro7573.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5780.jpg a /content/PetImages/Dog/perro7574.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1408.jpg a /content/PetImages/Dog/perro7575.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7713.jpg a /content/PetImages/Dog/perro7576.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12370.jpg a /content/PetImages/Dog/perro7577.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11768.jpg a /content/PetImages/Dog/perro7578.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3214.jpg a /content/PetImages/Dog/perro7579.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7985.jpg a /content/PetImages/Dog/perro7580.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9366.jpg a /content/PetImages/Dog/perro7581.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11808.jpg a /content/PetImages/Dog/perro7582.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_540.jpg a /content/PetImages/Dog/perro7583.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12245.jpg a /content/PetImages/Dog/perro7584.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5443.jpg a /content/PetImages/Dog/perro7585.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9179.jpg a /content/PetImages/Dog/perro7586.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6714.jpg a /content/PetImages/Dog/perro7587.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7436.jpg a /content/PetImages/Dog/perro7588.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_219.jpg a /content/PetImages/Dog/perro7589.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8517.jpg a /content/PetImages/Dog/perro7590.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12165.jpg a /content/PetImages/Dog/perro7591.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6243.jpg a /content/PetImages/Dog/perro7592.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10871.jpg a /content/PetImages/Dog/perro7593.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2288.jpg a /content/PetImages/Dog/perro7594.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6492.jpg a /content/PetImages/Dog/perro7595.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1517.jpg a /content/PetImages/Dog/perro7596.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3535.jpg a /content/PetImages/Dog/perro7597.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2109.jpg a /content/PetImages/Dog/perro7598.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9083.jpg a /content/PetImages/Dog/perro7599.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7843.jpg a /content/PetImages/Dog/perro7600.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11667.jpg a /content/PetImages/Dog/perro7601.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5091.jpg a /content/PetImages/Dog/perro7602.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9209.jpg a /content/PetImages/Dog/perro7603.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2719.jpg a /content/PetImages/Dog/perro7604.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_83.jpg a /content/PetImages/Dog/perro7605.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2267.jpg a /content/PetImages/Dog/perro7606.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7855.jpg a /content/PetImages/Dog/perro7607.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7727.jpg a /content/PetImages/Dog/perro7608.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7103.jpg a /content/PetImages/Dog/perro7609.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10899.jpg a /content/PetImages/Dog/perro7610.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7400.jpg a /content/PetImages/Dog/perro7611.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_590.jpg a /content/PetImages/Dog/perro7612.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4198.jpg a /content/PetImages/Dog/perro7613.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2086.jpg a /content/PetImages/Dog/perro7614.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4102.jpg a /content/PetImages/Dog/perro7615.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_981.jpg a /content/PetImages/Dog/perro7616.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7688.jpg a /content/PetImages/Dog/perro7617.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2115.jpg a /content/PetImages/Dog/perro7618.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3277.jpg a /content/PetImages/Dog/perro7619.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8574.jpg a /content/PetImages/Dog/perro7620.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_713.jpg a /content/PetImages/Dog/perro7621.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11052.jpg a /content/PetImages/Dog/perro7622.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9256.jpg a /content/PetImages/Dog/perro7623.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2995.jpg a /content/PetImages/Dog/perro7624.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9013.jpg a /content/PetImages/Dog/perro7625.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2421.jpg a /content/PetImages/Dog/perro7626.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6102.jpg a /content/PetImages/Dog/perro7627.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11996.jpg a /content/PetImages/Dog/perro7628.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2043.jpg a /content/PetImages/Dog/perro7629.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2710.jpg a /content/PetImages/Dog/perro7630.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9313.jpg a /content/PetImages/Dog/perro7631.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8502.jpg a /content/PetImages/Dog/perro7632.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3134.jpg a /content/PetImages/Dog/perro7633.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5784.jpg a /content/PetImages/Dog/perro7634.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11945.jpg a /content/PetImages/Dog/perro7635.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_205.jpg a /content/PetImages/Dog/perro7636.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4776.jpg a /content/PetImages/Dog/perro7637.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_816.jpg a /content/PetImages/Dog/perro7638.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8810.jpg a /content/PetImages/Dog/perro7639.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3467.jpg a /content/PetImages/Dog/perro7640.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2480.jpg a /content/PetImages/Dog/perro7641.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11665.jpg a /content/PetImages/Dog/perro7642.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7620.jpg a /content/PetImages/Dog/perro7643.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1590.jpg a /content/PetImages/Dog/perro7644.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3811.jpg a /content/PetImages/Dog/perro7645.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2238.jpg a /content/PetImages/Dog/perro7646.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11874.jpg a /content/PetImages/Dog/perro7647.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1821.jpg a /content/PetImages/Dog/perro7648.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1350.jpg a /content/PetImages/Dog/perro7649.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_957.jpg a /content/PetImages/Dog/perro7650.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1445.jpg a /content/PetImages/Dog/perro7651.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3055.jpg a /content/PetImages/Dog/perro7652.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1693.jpg a /content/PetImages/Dog/perro7653.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9931.jpg a /content/PetImages/Dog/perro7654.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11516.jpg a /content/PetImages/Dog/perro7655.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9627.jpg a /content/PetImages/Dog/perro7656.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10464.jpg a /content/PetImages/Dog/perro7657.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9387.jpg a /content/PetImages/Dog/perro7658.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7194.jpg a /content/PetImages/Dog/perro7659.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2485.jpg a /content/PetImages/Dog/perro7660.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4988.jpg a /content/PetImages/Dog/perro7661.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11490.jpg a /content/PetImages/Dog/perro7662.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5306.jpg a /content/PetImages/Dog/perro7663.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9564.jpg a /content/PetImages/Dog/perro7664.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6403.jpg a /content/PetImages/Dog/perro7665.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6239.jpg a /content/PetImages/Dog/perro7666.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4625.jpg a /content/PetImages/Dog/perro7667.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11348.jpg a /content/PetImages/Dog/perro7668.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5967.jpg a /content/PetImages/Dog/perro7669.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9530.jpg a /content/PetImages/Dog/perro7670.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2718.jpg a /content/PetImages/Dog/perro7671.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_194.jpg a /content/PetImages/Dog/perro7672.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3229.jpg a /content/PetImages/Dog/perro7673.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7237.jpg a /content/PetImages/Dog/perro7674.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2087.jpg a /content/PetImages/Dog/perro7675.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2095.jpg a /content/PetImages/Dog/perro7676.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11195.jpg a /content/PetImages/Dog/perro7677.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4271.jpg a /content/PetImages/Dog/perro7678.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_452.jpg a /content/PetImages/Dog/perro7679.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10947.jpg a /content/PetImages/Dog/perro7680.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2858.jpg a /content/PetImages/Dog/perro7681.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8766.jpg a /content/PetImages/Dog/perro7682.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7176.jpg a /content/PetImages/Dog/perro7683.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7309.jpg a /content/PetImages/Dog/perro7684.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4860.jpg a /content/PetImages/Dog/perro7685.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6253.jpg a /content/PetImages/Dog/perro7686.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5894.jpg a /content/PetImages/Dog/perro7687.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6966.jpg a /content/PetImages/Dog/perro7688.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6013.jpg a /content/PetImages/Dog/perro7689.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1970.jpg a /content/PetImages/Dog/perro7690.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10974.jpg a /content/PetImages/Dog/perro7691.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11623.jpg a /content/PetImages/Dog/perro7692.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10469.jpg a /content/PetImages/Dog/perro7693.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8918.jpg a /content/PetImages/Dog/perro7694.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2394.jpg a /content/PetImages/Dog/perro7695.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5250.jpg a /content/PetImages/Dog/perro7696.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4609.jpg a /content/PetImages/Dog/perro7697.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5120.jpg a /content/PetImages/Dog/perro7698.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2722.jpg a /content/PetImages/Dog/perro7699.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12397.jpg a /content/PetImages/Dog/perro7700.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2653.jpg a /content/PetImages/Dog/perro7701.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4155.jpg a /content/PetImages/Dog/perro7702.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4982.jpg a /content/PetImages/Dog/perro7703.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7030.jpg a /content/PetImages/Dog/perro7704.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2254.jpg a /content/PetImages/Dog/perro7705.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8799.jpg a /content/PetImages/Dog/perro7706.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2014.jpg a /content/PetImages/Dog/perro7707.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1316.jpg a /content/PetImages/Dog/perro7708.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1522.jpg a /content/PetImages/Dog/perro7709.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11074.jpg a /content/PetImages/Dog/perro7710.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1133.jpg a /content/PetImages/Dog/perro7711.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10116.jpg a /content/PetImages/Dog/perro7712.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12051.jpg a /content/PetImages/Dog/perro7713.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5582.jpg a /content/PetImages/Dog/perro7714.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2131.jpg a /content/PetImages/Dog/perro7715.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2201.jpg a /content/PetImages/Dog/perro7716.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6174.jpg a /content/PetImages/Dog/perro7717.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11177.jpg a /content/PetImages/Dog/perro7718.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_45.jpg a /content/PetImages/Dog/perro7719.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4523.jpg a /content/PetImages/Dog/perro7720.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11287.jpg a /content/PetImages/Dog/perro7721.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2849.jpg a /content/PetImages/Dog/perro7722.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7718.jpg a /content/PetImages/Dog/perro7723.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8939.jpg a /content/PetImages/Dog/perro7724.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8026.jpg a /content/PetImages/Dog/perro7725.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10376.jpg a /content/PetImages/Dog/perro7726.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7067.jpg a /content/PetImages/Dog/perro7727.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8286.jpg a /content/PetImages/Dog/perro7728.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1627.jpg a /content/PetImages/Dog/perro7729.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11435.jpg a /content/PetImages/Dog/perro7730.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1925.jpg a /content/PetImages/Dog/perro7731.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7267.jpg a /content/PetImages/Dog/perro7732.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4461.jpg a /content/PetImages/Dog/perro7733.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1201.jpg a /content/PetImages/Dog/perro7734.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10493.jpg a /content/PetImages/Dog/perro7735.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2144.jpg a /content/PetImages/Dog/perro7736.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4934.jpg a /content/PetImages/Dog/perro7737.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9543.jpg a /content/PetImages/Dog/perro7738.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10061.jpg a /content/PetImages/Dog/perro7739.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7352.jpg a /content/PetImages/Dog/perro7740.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11144.jpg a /content/PetImages/Dog/perro7741.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7490.jpg a /content/PetImages/Dog/perro7742.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4928.jpg a /content/PetImages/Dog/perro7743.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3848.jpg a /content/PetImages/Dog/perro7744.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9666.jpg a /content/PetImages/Dog/perro7745.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1927.jpg a /content/PetImages/Dog/perro7746.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7831.jpg a /content/PetImages/Dog/perro7747.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10756.jpg a /content/PetImages/Dog/perro7748.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3173.jpg a /content/PetImages/Dog/perro7749.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7665.jpg a /content/PetImages/Dog/perro7750.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11286.jpg a /content/PetImages/Dog/perro7751.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11235.jpg a /content/PetImages/Dog/perro7752.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6036.jpg a /content/PetImages/Dog/perro7753.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11149.jpg a /content/PetImages/Dog/perro7754.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9857.jpg a /content/PetImages/Dog/perro7755.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11496.jpg a /content/PetImages/Dog/perro7756.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11626.jpg a /content/PetImages/Dog/perro7757.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4778.jpg a /content/PetImages/Dog/perro7758.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7307.jpg a /content/PetImages/Dog/perro7759.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5850.jpg a /content/PetImages/Dog/perro7760.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8855.jpg a /content/PetImages/Dog/perro7761.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9099.jpg a /content/PetImages/Dog/perro7762.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1168.jpg a /content/PetImages/Dog/perro7763.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9464.jpg a /content/PetImages/Dog/perro7764.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9359.jpg a /content/PetImages/Dog/perro7765.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1962.jpg a /content/PetImages/Dog/perro7766.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6452.jpg a /content/PetImages/Dog/perro7767.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10938.jpg a /content/PetImages/Dog/perro7768.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7663.jpg a /content/PetImages/Dog/perro7769.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5993.jpg a /content/PetImages/Dog/perro7770.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12302.jpg a /content/PetImages/Dog/perro7771.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5021.jpg a /content/PetImages/Dog/perro7772.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4051.jpg a /content/PetImages/Dog/perro7773.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9057.jpg a /content/PetImages/Dog/perro7774.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1466.jpg a /content/PetImages/Dog/perro7775.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5842.jpg a /content/PetImages/Dog/perro7776.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10043.jpg a /content/PetImages/Dog/perro7777.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8639.jpg a /content/PetImages/Dog/perro7778.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9579.jpg a /content/PetImages/Dog/perro7779.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_434.jpg a /content/PetImages/Dog/perro7780.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6686.jpg a /content/PetImages/Dog/perro7781.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4413.jpg a /content/PetImages/Dog/perro7782.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8477.jpg a /content/PetImages/Dog/perro7783.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9244.jpg a /content/PetImages/Dog/perro7784.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7077.jpg a /content/PetImages/Dog/perro7785.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2626.jpg a /content/PetImages/Dog/perro7786.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11610.jpg a /content/PetImages/Dog/perro7787.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7029.jpg a /content/PetImages/Dog/perro7788.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10700.jpg a /content/PetImages/Dog/perro7789.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5331.jpg a /content/PetImages/Dog/perro7790.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11694.jpg a /content/PetImages/Dog/perro7791.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7807.jpg a /content/PetImages/Dog/perro7792.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10316.jpg a /content/PetImages/Dog/perro7793.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9777.jpg a /content/PetImages/Dog/perro7794.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9395.jpg a /content/PetImages/Dog/perro7795.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1027.jpg a /content/PetImages/Dog/perro7796.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1137.jpg a /content/PetImages/Dog/perro7797.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5490.jpg a /content/PetImages/Dog/perro7798.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11306.jpg a /content/PetImages/Dog/perro7799.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5821.jpg a /content/PetImages/Dog/perro7800.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11371.jpg a /content/PetImages/Dog/perro7801.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7398.jpg a /content/PetImages/Dog/perro7802.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5322.jpg a /content/PetImages/Dog/perro7803.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_159.jpg a /content/PetImages/Dog/perro7804.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5475.jpg a /content/PetImages/Dog/perro7805.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4848.jpg a /content/PetImages/Dog/perro7806.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3036.jpg a /content/PetImages/Dog/perro7807.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12316.jpg a /content/PetImages/Dog/perro7808.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6952.jpg a /content/PetImages/Dog/perro7809.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10315.jpg a /content/PetImages/Dog/perro7810.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11844.jpg a /content/PetImages/Dog/perro7811.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7160.jpg a /content/PetImages/Dog/perro7812.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_616.jpg a /content/PetImages/Dog/perro7813.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_723.jpg a /content/PetImages/Dog/perro7814.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_809.jpg a /content/PetImages/Dog/perro7815.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7916.jpg a /content/PetImages/Dog/perro7816.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9235.jpg a /content/PetImages/Dog/perro7817.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3502.jpg a /content/PetImages/Dog/perro7818.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5591.jpg a /content/PetImages/Dog/perro7819.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6747.jpg a /content/PetImages/Dog/perro7820.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7462.jpg a /content/PetImages/Dog/perro7821.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3142.jpg a /content/PetImages/Dog/perro7822.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6915.jpg a /content/PetImages/Dog/perro7823.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6758.jpg a /content/PetImages/Dog/perro7824.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3872.jpg a /content/PetImages/Dog/perro7825.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1389.jpg a /content/PetImages/Dog/perro7826.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1562.jpg a /content/PetImages/Dog/perro7827.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7838.jpg a /content/PetImages/Dog/perro7828.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11332.jpg a /content/PetImages/Dog/perro7829.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5584.jpg a /content/PetImages/Dog/perro7830.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7745.jpg a /content/PetImages/Dog/perro7831.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4375.jpg a /content/PetImages/Dog/perro7832.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9010.jpg a /content/PetImages/Dog/perro7833.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3270.jpg a /content/PetImages/Dog/perro7834.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5974.jpg a /content/PetImages/Dog/perro7835.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3292.jpg a /content/PetImages/Dog/perro7836.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3890.jpg a /content/PetImages/Dog/perro7837.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1030.jpg a /content/PetImages/Dog/perro7838.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5779.jpg a /content/PetImages/Dog/perro7839.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4421.jpg a /content/PetImages/Dog/perro7840.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7911.jpg a /content/PetImages/Dog/perro7841.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8347.jpg a /content/PetImages/Dog/perro7842.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2362.jpg a /content/PetImages/Dog/perro7843.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9193.jpg a /content/PetImages/Dog/perro7844.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_242.jpg a /content/PetImages/Dog/perro7845.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8131.jpg a /content/PetImages/Dog/perro7846.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9540.jpg a /content/PetImages/Dog/perro7847.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3710.jpg a /content/PetImages/Dog/perro7848.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_124.jpg a /content/PetImages/Dog/perro7849.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4661.jpg a /content/PetImages/Dog/perro7850.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10033.jpg a /content/PetImages/Dog/perro7851.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9339.jpg a /content/PetImages/Dog/perro7852.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9640.jpg a /content/PetImages/Dog/perro7853.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9760.jpg a /content/PetImages/Dog/perro7854.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11891.jpg a /content/PetImages/Dog/perro7855.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6909.jpg a /content/PetImages/Dog/perro7856.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7571.jpg a /content/PetImages/Dog/perro7857.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1480.jpg a /content/PetImages/Dog/perro7858.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7314.jpg a /content/PetImages/Dog/perro7859.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1577.jpg a /content/PetImages/Dog/perro7860.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4232.jpg a /content/PetImages/Dog/perro7861.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9072.jpg a /content/PetImages/Dog/perro7862.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5470.jpg a /content/PetImages/Dog/perro7863.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1470.jpg a /content/PetImages/Dog/perro7864.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_448.jpg a /content/PetImages/Dog/perro7865.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1252.jpg a /content/PetImages/Dog/perro7866.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9106.jpg a /content/PetImages/Dog/perro7867.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1974.jpg a /content/PetImages/Dog/perro7868.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10438.jpg a /content/PetImages/Dog/perro7869.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2628.jpg a /content/PetImages/Dog/perro7870.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9915.jpg a /content/PetImages/Dog/perro7871.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4657.jpg a /content/PetImages/Dog/perro7872.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8970.jpg a /content/PetImages/Dog/perro7873.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_633.jpg a /content/PetImages/Dog/perro7874.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5541.jpg a /content/PetImages/Dog/perro7875.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_472.jpg a /content/PetImages/Dog/perro7876.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11566.jpg a /content/PetImages/Dog/perro7877.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8306.jpg a /content/PetImages/Dog/perro7878.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4075.jpg a /content/PetImages/Dog/perro7879.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6821.jpg a /content/PetImages/Dog/perro7880.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5469.jpg a /content/PetImages/Dog/perro7881.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9031.jpg a /content/PetImages/Dog/perro7882.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2385.jpg a /content/PetImages/Dog/perro7883.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4514.jpg a /content/PetImages/Dog/perro7884.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9975.jpg a /content/PetImages/Dog/perro7885.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8736.jpg a /content/PetImages/Dog/perro7886.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8462.jpg a /content/PetImages/Dog/perro7887.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2471.jpg a /content/PetImages/Dog/perro7888.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4812.jpg a /content/PetImages/Dog/perro7889.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2295.jpg a /content/PetImages/Dog/perro7890.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5380.jpg a /content/PetImages/Dog/perro7891.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2465.jpg a /content/PetImages/Dog/perro7892.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1809.jpg a /content/PetImages/Dog/perro7893.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6160.jpg a /content/PetImages/Dog/perro7894.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5310.jpg a /content/PetImages/Dog/perro7895.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2556.jpg a /content/PetImages/Dog/perro7896.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_197.jpg a /content/PetImages/Dog/perro7897.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9255.jpg a /content/PetImages/Dog/perro7898.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8409.jpg a /content/PetImages/Dog/perro7899.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9322.jpg a /content/PetImages/Dog/perro7900.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10832.jpg a /content/PetImages/Dog/perro7901.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6240.jpg a /content/PetImages/Dog/perro7902.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5079.jpg a /content/PetImages/Dog/perro7903.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5897.jpg a /content/PetImages/Dog/perro7904.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8625.jpg a /content/PetImages/Dog/perro7905.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3416.jpg a /content/PetImages/Dog/perro7906.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2441.jpg a /content/PetImages/Dog/perro7907.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5204.jpg a /content/PetImages/Dog/perro7908.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7867.jpg a /content/PetImages/Dog/perro7909.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9780.jpg a /content/PetImages/Dog/perro7910.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3111.jpg a /content/PetImages/Dog/perro7911.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9353.jpg a /content/PetImages/Dog/perro7912.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10648.jpg a /content/PetImages/Dog/perro7913.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7141.jpg a /content/PetImages/Dog/perro7914.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4294.jpg a /content/PetImages/Dog/perro7915.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11132.jpg a /content/PetImages/Dog/perro7916.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1372.jpg a /content/PetImages/Dog/perro7917.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6999.jpg a /content/PetImages/Dog/perro7918.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10280.jpg a /content/PetImages/Dog/perro7919.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3027.jpg a /content/PetImages/Dog/perro7920.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10716.jpg a /content/PetImages/Dog/perro7921.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6858.jpg a /content/PetImages/Dog/perro7922.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12162.jpg a /content/PetImages/Dog/perro7923.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11018.jpg a /content/PetImages/Dog/perro7924.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6392.jpg a /content/PetImages/Dog/perro7925.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1052.jpg a /content/PetImages/Dog/perro7926.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5436.jpg a /content/PetImages/Dog/perro7927.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10177.jpg a /content/PetImages/Dog/perro7928.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3615.jpg a /content/PetImages/Dog/perro7929.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_622.jpg a /content/PetImages/Dog/perro7930.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4038.jpg a /content/PetImages/Dog/perro7931.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6368.jpg a /content/PetImages/Dog/perro7932.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3050.jpg a /content/PetImages/Dog/perro7933.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7295.jpg a /content/PetImages/Dog/perro7934.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10321.jpg a /content/PetImages/Dog/perro7935.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11817.jpg a /content/PetImages/Dog/perro7936.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4902.jpg a /content/PetImages/Dog/perro7937.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9495.jpg a /content/PetImages/Dog/perro7938.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5491.jpg a /content/PetImages/Dog/perro7939.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10473.jpg a /content/PetImages/Dog/perro7940.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12372.jpg a /content/PetImages/Dog/perro7941.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3066.jpg a /content/PetImages/Dog/perro7942.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12389.jpg a /content/PetImages/Dog/perro7943.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7031.jpg a /content/PetImages/Dog/perro7944.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2857.jpg a /content/PetImages/Dog/perro7945.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3508.jpg a /content/PetImages/Dog/perro7946.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9693.jpg a /content/PetImages/Dog/perro7947.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3090.jpg a /content/PetImages/Dog/perro7948.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1449.jpg a /content/PetImages/Dog/perro7949.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11000.jpg a /content/PetImages/Dog/perro7950.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6722.jpg a /content/PetImages/Dog/perro7951.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9102.jpg a /content/PetImages/Dog/perro7952.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10931.jpg a /content/PetImages/Dog/perro7953.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2939.jpg a /content/PetImages/Dog/perro7954.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7621.jpg a /content/PetImages/Dog/perro7955.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4260.jpg a /content/PetImages/Dog/perro7956.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8940.jpg a /content/PetImages/Dog/perro7957.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7552.jpg a /content/PetImages/Dog/perro7958.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10590.jpg a /content/PetImages/Dog/perro7959.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3656.jpg a /content/PetImages/Dog/perro7960.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8887.jpg a /content/PetImages/Dog/perro7961.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8683.jpg a /content/PetImages/Dog/perro7962.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5928.jpg a /content/PetImages/Dog/perro7963.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6648.jpg a /content/PetImages/Dog/perro7964.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6481.jpg a /content/PetImages/Dog/perro7965.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12192.jpg a /content/PetImages/Dog/perro7966.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11165.jpg a /content/PetImages/Dog/perro7967.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6896.jpg a /content/PetImages/Dog/perro7968.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_853.jpg a /content/PetImages/Dog/perro7969.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4253.jpg a /content/PetImages/Dog/perro7970.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11697.jpg a /content/PetImages/Dog/perro7971.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8212.jpg a /content/PetImages/Dog/perro7972.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1.jpg a /content/PetImages/Dog/perro7973.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12246.jpg a /content/PetImages/Dog/perro7974.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3943.jpg a /content/PetImages/Dog/perro7975.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5348.jpg a /content/PetImages/Dog/perro7976.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7993.jpg a /content/PetImages/Dog/perro7977.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5489.jpg a /content/PetImages/Dog/perro7978.jpg
# ...
# Se cambió el nombre de /content/PetImages/Dog/perro_7329.jpg a /content/PetImages/Dog/perro12343.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8573.jpg a /content/PetImages/Dog/perro12344.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5849.jpg a /content/PetImages/Dog/perro12345.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12004.jpg a /content/PetImages/Dog/perro12346.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7757.jpg a /content/PetImages/Dog/perro12347.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11900.jpg a /content/PetImages/Dog/perro12348.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_720.jpg a /content/PetImages/Dog/perro12349.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8997.jpg a /content/PetImages/Dog/perro12350.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11255.jpg a /content/PetImages/Dog/perro12351.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8499.jpg a /content/PetImages/Dog/perro12352.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7201.jpg a /content/PetImages/Dog/perro12353.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1614.jpg a /content/PetImages/Dog/perro12354.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9622.jpg a /content/PetImages/Dog/perro12355.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3614.jpg a /content/PetImages/Dog/perro12356.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3120.jpg a /content/PetImages/Dog/perro12357.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4820.jpg a /content/PetImages/Dog/perro12358.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11251.jpg a /content/PetImages/Dog/perro12359.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1818.jpg a /content/PetImages/Dog/perro12360.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9332.jpg a /content/PetImages/Dog/perro12361.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10910.jpg a /content/PetImages/Dog/perro12362.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12151.jpg a /content/PetImages/Dog/perro12363.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11309.jpg a /content/PetImages/Dog/perro12364.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2203.jpg a /content/PetImages/Dog/perro12365.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4086.jpg a /content/PetImages/Dog/perro12366.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3626.jpg a /content/PetImages/Dog/perro12367.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4712.jpg a /content/PetImages/Dog/perro12368.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8276.jpg a /content/PetImages/Dog/perro12369.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11466.jpg a /content/PetImages/Dog/perro12370.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_858.jpg a /content/PetImages/Dog/perro12371.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8136.jpg a /content/PetImages/Dog/perro12372.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4770.jpg a /content/PetImages/Dog/perro12373.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12155.jpg a /content/PetImages/Dog/perro12374.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3977.jpg a /content/PetImages/Dog/perro12375.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7091.jpg a /content/PetImages/Dog/perro12376.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8608.jpg a /content/PetImages/Dog/perro12377.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3748.jpg a /content/PetImages/Dog/perro12378.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5594.jpg a /content/PetImages/Dog/perro12379.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3799.jpg a /content/PetImages/Dog/perro12380.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9242.jpg a /content/PetImages/Dog/perro12381.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3443.jpg a /content/PetImages/Dog/perro12382.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8485.jpg a /content/PetImages/Dog/perro12383.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9309.jpg a /content/PetImages/Dog/perro12384.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1412.jpg a /content/PetImages/Dog/perro12385.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10373.jpg a /content/PetImages/Dog/perro12386.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5382.jpg a /content/PetImages/Dog/perro12387.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5164.jpg a /content/PetImages/Dog/perro12388.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10261.jpg a /content/PetImages/Dog/perro12389.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3379.jpg a /content/PetImages/Dog/perro12390.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1873.jpg a /content/PetImages/Dog/perro12391.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6070.jpg a /content/PetImages/Dog/perro12392.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10192.jpg a /content/PetImages/Dog/perro12393.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9298.jpg a /content/PetImages/Dog/perro12394.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8328.jpg a /content/PetImages/Dog/perro12395.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10887.jpg a /content/PetImages/Dog/perro12396.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7963.jpg a /content/PetImages/Dog/perro12397.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9175.jpg a /content/PetImages/Dog/perro12398.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12144.jpg a /content/PetImages/Dog/perro12399.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9094.jpg a /content/PetImages/Dog/perro12400.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5647.jpg a /content/PetImages/Dog/perro12401.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4579.jpg a /content/PetImages/Dog/perro12402.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9413.jpg a /content/PetImages/Dog/perro12403.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9292.jpg a /content/PetImages/Dog/perro12404.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5606.jpg a /content/PetImages/Dog/perro12405.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2721.jpg a /content/PetImages/Dog/perro12406.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4537.jpg a /content/PetImages/Dog/perro12407.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5425.jpg a /content/PetImages/Dog/perro12408.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10508.jpg a /content/PetImages/Dog/perro12409.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4444.jpg a /content/PetImages/Dog/perro12410.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7494.jpg a /content/PetImages/Dog/perro12411.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9696.jpg a /content/PetImages/Dog/perro12412.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4638.jpg a /content/PetImages/Dog/perro12413.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3739.jpg a /content/PetImages/Dog/perro12414.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11488.jpg a /content/PetImages/Dog/perro12415.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11893.jpg a /content/PetImages/Dog/perro12416.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11765.jpg a /content/PetImages/Dog/perro12417.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7399.jpg a /content/PetImages/Dog/perro12418.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7906.jpg a /content/PetImages/Dog/perro12419.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11829.jpg a /content/PetImages/Dog/perro12420.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1333.jpg a /content/PetImages/Dog/perro12421.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2469.jpg a /content/PetImages/Dog/perro12422.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5563.jpg a /content/PetImages/Dog/perro12423.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11707.jpg a /content/PetImages/Dog/perro12424.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2634.jpg a /content/PetImages/Dog/perro12425.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6122.jpg a /content/PetImages/Dog/perro12426.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7824.jpg a /content/PetImages/Dog/perro12427.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7821.jpg a /content/PetImages/Dog/perro12428.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6610.jpg a /content/PetImages/Dog/perro12429.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4502.jpg a /content/PetImages/Dog/perro12430.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5794.jpg a /content/PetImages/Dog/perro12431.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6395.jpg a /content/PetImages/Dog/perro12432.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7835.jpg a /content/PetImages/Dog/perro12433.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12486.jpg a /content/PetImages/Dog/perro12434.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5346.jpg a /content/PetImages/Dog/perro12435.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10770.jpg a /content/PetImages/Dog/perro12436.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4658.jpg a /content/PetImages/Dog/perro12437.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5122.jpg a /content/PetImages/Dog/perro12438.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_403.jpg a /content/PetImages/Dog/perro12439.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9609.jpg a /content/PetImages/Dog/perro12440.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1740.jpg a /content/PetImages/Dog/perro12441.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2631.jpg a /content/PetImages/Dog/perro12442.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9637.jpg a /content/PetImages/Dog/perro12443.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11995.jpg a /content/PetImages/Dog/perro12444.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9716.jpg a /content/PetImages/Dog/perro12445.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12283.jpg a /content/PetImages/Dog/perro12446.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1207.jpg a /content/PetImages/Dog/perro12447.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11475.jpg a /content/PetImages/Dog/perro12448.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2090.jpg a /content/PetImages/Dog/perro12449.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4929.jpg a /content/PetImages/Dog/perro12450.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2531.jpg a /content/PetImages/Dog/perro12451.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_839.jpg a /content/PetImages/Dog/perro12452.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10214.jpg a /content/PetImages/Dog/perro12453.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_4888.jpg a /content/PetImages/Dog/perro12454.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7504.jpg a /content/PetImages/Dog/perro12455.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_12398.jpg a /content/PetImages/Dog/perro12456.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1244.jpg a /content/PetImages/Dog/perro12457.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_604.jpg a /content/PetImages/Dog/perro12458.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10862.jpg a /content/PetImages/Dog/perro12459.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_579.jpg a /content/PetImages/Dog/perro12460.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2449.jpg a /content/PetImages/Dog/perro12461.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_269.jpg a /content/PetImages/Dog/perro12462.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1363.jpg a /content/PetImages/Dog/perro12463.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8522.jpg a /content/PetImages/Dog/perro12464.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5837.jpg a /content/PetImages/Dog/perro12465.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2770.jpg a /content/PetImages/Dog/perro12466.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3910.jpg a /content/PetImages/Dog/perro12467.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7592.jpg a /content/PetImages/Dog/perro12468.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5244.jpg a /content/PetImages/Dog/perro12469.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5653.jpg a /content/PetImages/Dog/perro12470.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1828.jpg a /content/PetImages/Dog/perro12471.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3846.jpg a /content/PetImages/Dog/perro12472.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10544.jpg a /content/PetImages/Dog/perro12473.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2887.jpg a /content/PetImages/Dog/perro12474.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2589.jpg a /content/PetImages/Dog/perro12475.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_9066.jpg a /content/PetImages/Dog/perro12476.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8062.jpg a /content/PetImages/Dog/perro12477.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2807.jpg a /content/PetImages/Dog/perro12478.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1510.jpg a /content/PetImages/Dog/perro12479.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11151.jpg a /content/PetImages/Dog/perro12480.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2379.jpg a /content/PetImages/Dog/perro12481.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11313.jpg a /content/PetImages/Dog/perro12482.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5391.jpg a /content/PetImages/Dog/perro12483.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10921.jpg a /content/PetImages/Dog/perro12484.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_166.jpg a /content/PetImages/Dog/perro12485.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6774.jpg a /content/PetImages/Dog/perro12486.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10347.jpg a /content/PetImages/Dog/perro12487.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8920.jpg a /content/PetImages/Dog/perro12488.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2517.jpg a /content/PetImages/Dog/perro12489.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_2039.jpg a /content/PetImages/Dog/perro12490.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_11979.jpg a /content/PetImages/Dog/perro12491.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_802.jpg a /content/PetImages/Dog/perro12492.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_6563.jpg a /content/PetImages/Dog/perro12493.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_1435.jpg a /content/PetImages/Dog/perro12494.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_3303.jpg a /content/PetImages/Dog/perro12495.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5440.jpg a /content/PetImages/Dog/perro12496.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_7536.jpg a /content/PetImages/Dog/perro12497.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_10194.jpg a /content/PetImages/Dog/perro12498.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_5049.jpg a /content/PetImages/Dog/perro12499.jpg
# Se cambió el nombre de /content/PetImages/Dog/perro_8491.jpg a /content/PetImages/Dog/perro12500.jpg

# %%
#@markdown # *1) ** Creacion de el csv de los path y clases(OBLIGATORIO)
import os
import pandas as pd
def crear_paths_csv(directorio_base,clases_lista,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir,clase in  zip(directorio_base,clases_lista,clases):

    for path  in (dir):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")

directorio_gato="/content/PetImages/Cat/"
directorio_perro="/content/PetImages/Dog/"

gato_lista=os.listdir(directorio_gato)
perro_list=os.listdir(directorio_perro)

crear_paths_csv([directorio_gato,directorio_perro],[gato_lista,perro_list],[0,1],"Data_set_paths.csv")
# Out:
# Csv Creado

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd

import sklearn
import cv2
from PIL import Image


class MiDataSet(Dataset):

  def __init__(self,csv_file, transform=None):


     self.data=pd.read_csv(csv_file)

     self.x=self.data["path"]
     self.y=self.data["etiqueta"]

     self.transform=transform

     self.samples=self.data["path"].shape[0]


  def __getitem__(self,id):

    rut_imagen=self.x[id]
    imagen=cv2.imread(rut_imagen)
    etiqueta=self.y[id]

    if imagen is None:
     print(f"No se pudo cargar la imagen en {rut_imagen}.")


    imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)


    if self.transform:
      imagen_rgb = self.transform(imagen_rgb)

    return imagen_rgb,etiqueta


  def __len__(self):
   return self.samples

# %%
#@markdown # *3) ** Separacion dos archivos difentes para entrenamietno y prueba(OBLIGATORIO)

from sklearn.model_selection import train_test_split

misdatos=pd.read_csv("/content/Data_set_paths.csv")
# Separo mis datos en entrenamiento y test
datos_entrenamiento, datos_evaluacion = train_test_split(misdatos, test_size=0.3, random_state=42)


# Guardar los dos conjuntos en archivos CSV separados
datos_entrenamiento.to_csv("/content/datos_entrenamiento.csv", index=False)
datos_evaluacion.to_csv("/content/datos_evaluacion.csv", index=False)

# %%
#@markdown # *2) ** Mostrar 20 muestras(Opcional)
import matplotlib.pyplot as plt
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from PIL import Image


# Definir transformaciones
transformaciones = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((100, 100))
])

# Crear dataset y DataLoader
muestra = MiDataSet("/content/datos_entrenamiento.csv", transformaciones)
data_muestra = DataLoader(muestra, batch_size=20, shuffle=True)

# Obtener el primer lote
primer_lote = next(iter(data_muestra))
tensor_imagenes, tensor_etiquetas = primer_lote

# Mapeo de etiquetas numéricas a etiquetas de texto
mapeo_etiquetas = {0: 'gato', 1: 'perro'}
etiquetas_texto = [mapeo_etiquetas[item.item()] for item in tensor_etiquetas]

# Crear una figura y subgráficos
fig, axs = plt.subplots(4, 5, figsize=(20, 20))

# Iterar sobre las imágenes del lote
for i in range(4):
    for j in range(5):
        idx = i * 5 + j
        imagen = tensor_imagenes[idx].permute(1, 2, 0)
        etiqueta_texto = etiquetas_texto[idx]

        # Mostrar la imagen en el subgráfico correspondiente
        axs[i, j].imshow(imagen)
        axs[i, j].set_title(etiqueta_texto)
        axs[i, j].axis('off')

plt.show()

# %%
import sklearn

from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset

transformaciones = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((100, 100))
])

mis_datos_entrenamiento=MiDataSet("/content/datos_entrenamiento.csv",transform=transformaciones)

mis_datos_test=MiDataSet("/content/datos_evaluacion.csv",transform=transformaciones)


data_por_lote_entrenamiento=DataLoader(mis_datos_entrenamiento,batch_size=5,shuffle=True)

data_por_por_lote_test=DataLoader(mis_datos_test,batch_size=5,shuffle=True)

# %%
import torch.nn as nn
import torch.nn.functional as F



class RedConvolucional(nn.Module):

   def __init__(self):
    super(RedConvolucional,self).__init__()

#Red convolulcional

    self.conv1=nn.Conv2d(in_channels=3,out_channels=6,kernel_size=3, stride=1, padding=1)
    self.conv2=nn.Conv2d(in_channels=6,out_channels=12,kernel_size=3, stride=1, padding=1)
    self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2)

    self.conv3=nn.Conv2d(in_channels=12,out_channels=24,kernel_size=3, stride=1, padding=1)
    self.maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2)

    self.conv4=nn.Conv2d(in_channels=24,out_channels=48,kernel_size=3, stride=2, padding=1)
    self.maxpool3 = nn.MaxPool2d(kernel_size=2, stride=2)

    self.flatten=nn.Flatten()

#Red fully conected o multicapa convecional

    self.capa_oculta=nn.Linear(1728,100)

    self.capa_salida=nn.Linear(100,2)


   def forward(self,x):
    #Capa convolucionales
     x=self.conv1(x)
     x=F.relu(x)

     x=self.conv2(x)
     x=F.relu(x)
     x=self.maxpool1(x)

     x=self.conv3(x)
     x=F.relu(x)
     x=self.maxpool2(x)

     x=self.conv4(x)
     x=F.relu(x)
     x=self.maxpool3(x)
     x=self.flatten(x)

#Capa fully conected
     x=self.capa_oculta(x)
     x=F.relu(x)

     x=self.capa_salida(x)
     output=F.softmax(x, dim=-1)




     return output

# %%
#funcion clasificador:
def clasificador(y_pred_test):
 max_values_tensor=torch.empty((0,),dtype=torch.float32)

 for tensor in y_pred_test:
   max_values,max_indices=torch.max(tensor,dim=0)

   max_values_tensor=torch.cat((max_values_tensor,max_indices.unsqueeze(0)))

 return max_values_tensor

#funcion acutity:
def accurity(y_test,y_real):
   correctos=0
   for predicho, real in zip(y_test, y_real):
    if predicho==real:
     correctos+=1
   return correctos/len(y_test)


import torch.optim as optim


ModeloRC=RedConvolucional()

criterio=nn.BCEWithLogitsLoss()

optimizer=optim.SGD(ModeloRC.parameters(),lr=0.1)

epochs=6

for epoch in range(epochs):

 for i,(xi,yi) in enumerate(data_por_lote_entrenamiento):

    y_predict=ModeloRC(xi)
    y_predic_train_clasificado=clasificador(y_predict)

    loss=criterio(y_predic_train_clasificado,yi.float())
    print(f'Epoca[{epoch+1}],Perdida: {loss.item():.4f} ')


 loss.backward()
 optimizer.step()
 optimizer.zero_grad()

 with torch.no_grad():
   for i,(xi,yi) in enumerate(data_por_por_lote_test):
    y_predict_test=ModeloRC(xi)
    y_predic_test_clasificado=clasificador(yi)

   Precision=accurity(y_predict_test,y_predic_test_clasificado)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoca[1],Perdida: 0.5133
# Epoca[1],Perdida: 1.1133
# Epoca[1],Perdida: 1.3133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 1.1133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 1.1133
# Epoca[1],Perdida: 0.5133
# Epoca[1],Perdida: 0.3133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 1.1133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 1.1133
# Epoca[1],Perdida: 0.5133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 1.1133
# Epoca[1],Perdida: 0.5133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.9133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 0.7133
# Epoca[1],Perdida: 0.5133
# No se pudo cargar la imagen en /content/PetImages/Dog/perro2887.jpg.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-38-19f4a2340f98> in <cell line: 32>()
#      32 for epoch in range(epochs):
#      33
# ---> 34  for i,(xi,yi) in enumerate(data_por_lote_entrenamiento):
#      35
#      36     y_predict=ModeloRC(xi)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-34-62bda5c96653> in __getitem__(self, id)
#      34
#      35
# ---> 36     imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
#      37
#      38
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
y_pred_multiclases = torch.tensor([[0.1, 1.8, 0.8, 0.4, 2],
                                   [0.5, 2, 3.5, 5, 2.1]])

def clasificador(y_pred_test):

   max_values_tensor = torch.empty((0,), dtype=torch.float32)

   for tensor in y_pred_test:

     max_values, max_indices  = torch.max(tensor, dim=0)

     max_values_tensor = torch.cat((max_values_tensor, max_indices.unsqueeze(0)))

   return max_values_tensor

print(clasificador(y_pred_multiclases))
# Out:
# tensor([4., 3.])
